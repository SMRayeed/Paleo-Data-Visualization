# %% [markdown]
# <a href="https://colab.research.google.com/github/SMRayeed/Paleo-Data-Visualization/blob/main/01_Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
from io import StringIO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = '/content/drive/MyDrive/AI4C-Project-init/'
files = os.listdir(folder_path)

# %%
print(f"Files with distinct names \t ----->  {len(set(files))}")
non_distinct_files = [item for item in files if files.count(item) > 1]
print(f"Files with non-distinct names \t ----->  {len(non_distinct_files)}")
# Out:
# Files with distinct names 	 ----->  558
# Files with non-distinct names 	 ----->  0

# %%
drive_path_txt = '/content/drive/MyDrive/AI4C-Project/New-Data/Files(.txt)/'
drive_path_csv = '/content/drive/MyDrive/AI4C-Project/New-Data/Files(.csv)/'
os.makedirs(drive_path_txt) if not os.path.exists(drive_path_txt) else None
os.makedirs(drive_path_csv) if not os.path.exists(drive_path_csv) else None

# %%
min_info, avg_info, max_info, len_info = [], [], [], []

# %%
early, late = [], []

# %%
ix = 1

for file in files :

  print(" ====== S T A R T I N G ====== : ", file)

  file_path = folder_path + file

  with open(file_path, 'r') as file : text_data = file.read()

  site_name = text_data.split('Site_Name: ')[1].split('\n')[0].strip()
  location = text_data.split('Location: ')[1].split('\n')[0].strip()
  northernmost_latitude = float(text_data.split('Northernmost_Latitude: ')[1].split('\n')[0].strip())
  southernmost_latitude = float(text_data.split('Southernmost_Latitude: ')[1].split('\n')[0].strip())
  easternmost_longitude = float(text_data.split('Easternmost_Longitude: ')[1].split('\n')[0].strip())
  westernmost_longitude = float(text_data.split('Westernmost_Longitude: ')[1].split('\n')[0].strip())

  collection_name = text_data.split('Collection_Name: ')[1].split('\n')[0].strip()
  first_year = int((text_data.split('First_Year: ')[1].split('\n')[0].strip()) or (text_data.split('Earliest_Year: ')[1].split('\n')[0].strip()))
  last_year = int((text_data.split('Last_Year: ')[1].split('\n')[0].strip()) or (text_data.split('Most_Recent_Year: ')[1].split('\n')[0].strip()))

  early.append(first_year)
  late.append(last_year)
  species_name = text_data.split('Species_Name: ')[1].split('\n')[0].strip()
  common_name = text_data.split('Common_Name: ')[1].split('\n')[0].strip()
  tree_species_code = text_data.split('Tree_Species_Code: ')[1].split('\n')[0].strip()

  output_txt_file_name = f"{collection_name}.txt"
  output_txt_file_path = drive_path_txt + output_txt_file_name

  with open(output_txt_file_path, 'w') as output_file:
    output_file.write("Site Information\n")
    output_file.write("================\n")
    output_file.write(f"Site Name: {site_name}\n")
    output_file.write(f"Location: {location}\n")
    output_file.write(f"Northernmost Latitude: {northernmost_latitude}\n")
    output_file.write(f"Southernmost Latitude: {southernmost_latitude}\n")
    output_file.write(f"Easternmost Longitude: {easternmost_longitude}\n")
    output_file.write(f"Westernmost Longitude: {westernmost_longitude}\n")

    output_file.write("Data Collection\n")
    output_file.write("===============\n")
    output_file.write(f"Collection Name: {collection_name}\n")
    output_file.write(f"First Year: {first_year}\n")
    output_file.write(f"Last Year: {last_year}\n\n")

    output_file.write("Species Information\n")
    output_file.write("===================\n")
    output_file.write(f"Species Name: {species_name}\n")
    output_file.write(f"Common Name: {common_name}\n")
    output_file.write(f"Tree Species Code: {tree_species_code}\n")

  data_start_line = next(i for i, line in enumerate(text_data.strip().split('\n')) if line.startswith('age_CE') and not line.startswith('##'))
  df = pd.read_csv(StringIO(text_data), delim_whitespace=True, skiprows=data_start_line, index_col='age_CE')
  df.index.name = 'trees'
  df = df.transpose()
  df['site'] = site_name
  df['loc'] = location
  df['N'] = northernmost_latitude
  df['S'] = southernmost_latitude
  df['E'] = easternmost_longitude
  df['W'] = easternmost_longitude
  df['species'] = tree_species_code
  df = df.reset_index()

  output_csv_file_name = f"{collection_name}.csv"
  output_csv_file_path = drive_path_csv + output_csv_file_name
  df.to_csv(output_csv_file_path, index=False)

  non_nan_counts = df.iloc[:, :-7].notna().sum(axis=1)
  df_min_tree = non_nan_counts.idxmin()
  df_min = non_nan_counts[df_min_tree]
  df_max_tree = non_nan_counts.idxmax()
  df_max = non_nan_counts[df_max_tree]
  df_avg = non_nan_counts.mean()

  print(f"Min : {df_min} \t---> Tree : {df_min_tree}")
  print(f"Max : {df_max} \t---> Tree : {df_max_tree}")
  print(f"Avg : {df_avg:.4f}")

  min_info.append(df_min)
  avg_info.append(df_avg)
  max_info.append(df_max)
  len_info.append(len(df))

  print(f"====== D O N E ====== : {ix} of {len(files)} Files\n\n")

  ix += 1
# Out:
#  ====== S T A R T I N G ====== :  wa040-rwl-noaa.txt
# Min : 92 	---> Tree : 1
# Max : 372 	---> Tree : 8
# Avg : 209.5625
# ====== D O N E ====== : 1 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  or082-rwl-noaa.txt
# Min : 58 	---> Tree : 27
# Max : 264 	---> Tree : 45
# Avg : 107.2041
# ====== D O N E ====== : 2 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wa057-rwl-noaa.txt
# Min : 212 	---> Tree : 9
# Max : 552 	---> Tree : 11
# Avg : 345.1364
# ====== D O N E ====== : 3 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca604-rwl-noaa.txt
# Min : 98 	---> Tree : 23
# Max : 333 	---> Tree : 5
# Avg : 184.0000
# ====== D O N E ====== : 4 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mt158-rwl-noaa.txt
# Min : 78 	---> Tree : 55
# Max : 621 	---> Tree : 18
# Avg : 257.3944
# ====== D O N E ====== : 5 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy050-rwl-noaa.txt
# Min : 75 	---> Tree : 1
# Max : 663 	---> Tree : 27
# Avg : 222.9787
# ====== D O N E ====== : 6 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy033-rwl-noaa.txt
# Min : 79 	---> Tree : 20
# Max : 666 	---> Tree : 9
# Avg : 243.6538
# ====== D O N E ====== : 7 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca603-rwl-noaa.txt
# Min : 76 	---> Tree : 28
# Max : 453 	---> Tree : 9
# Avg : 211.8621
# ====== D O N E ====== : 8 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy071-rwl-noaa.txt
# Min : 25 	---> Tree : 3
# Max : 181 	---> Tree : 73
# Avg : 82.1197
# ====== D O N E ====== : 9 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca602-rwl-noaa.txt
# Min : 93 	---> Tree : 2
# Max : 461 	---> Tree : 16
# Avg : 244.4595
# ====== D O N E ====== : 10 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca605-rwl-noaa.txt
# Min : 88 	---> Tree : 54
# Max : 436 	---> Tree : 8
# Avg : 216.8909
# ====== D O N E ====== : 11 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mt172-rwl-noaa.txt
# Min : 105 	---> Tree : 16
# Max : 438 	---> Tree : 36
# Avg : 222.7083
# ====== D O N E ====== : 12 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca606-rwl-noaa.txt
# Min : 90 	---> Tree : 20
# Max : 453 	---> Tree : 22
# Avg : 206.4324
# ====== D O N E ====== : 13 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  id012-rwl-noaa.txt
# Min : 144 	---> Tree : 23
# Max : 675 	---> Tree : 2
# Avg : 335.1667
# ====== D O N E ====== : 14 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  id011-rwl-noaa.txt
# Min : 65 	---> Tree : 36
# Max : 767 	---> Tree : 15
# Avg : 366.1154
# ====== D O N E ====== : 15 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wa068-rwl-noaa.txt
# Min : 102 	---> Tree : 24
# Max : 323 	---> Tree : 11
# Avg : 208.6667
# ====== D O N E ====== : 16 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  id009-rwl-noaa.txt
# Min : 64 	---> Tree : 10
# Max : 761 	---> Tree : 2
# Avg : 356.6552
# ====== D O N E ====== : 17 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  id010-rwl-noaa.txt
# Min : 74 	---> Tree : 4
# Max : 795 	---> Tree : 26
# Avg : 424.4324
# ====== D O N E ====== : 18 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co525-rwl-noaa.txt
# Min : 169 	---> Tree : 24
# Max : 912 	---> Tree : 15
# Avg : 477.1053
# ====== D O N E ====== : 19 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co672-rwl-noaa.txt
# Min : 133 	---> Tree : 15
# Max : 1666 	---> Tree : 39
# Avg : 484.6731
# ====== D O N E ====== : 20 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co562-rwl-noaa.txt
# Min : 189 	---> Tree : 3
# Max : 816 	---> Tree : 15
# Avg : 403.4444
# ====== D O N E ====== : 21 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co522-rwl-noaa.txt
# Min : 217 	---> Tree : 29
# Max : 1348 	---> Tree : 8
# Avg : 635.0968
# ====== D O N E ====== : 22 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co523-rwl-noaa.txt
# Min : 213 	---> Tree : 12
# Max : 937 	---> Tree : 9
# Avg : 491.6207
# ====== D O N E ====== : 23 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az510-rwl-noaa.txt
# Min : 253 	---> Tree : 21
# Max : 1437 	---> Tree : 4
# Avg : 624.1667
# ====== D O N E ====== : 24 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co524-rwl-noaa.txt
# Min : 187 	---> Tree : 38
# Max : 1214 	---> Tree : 24
# Avg : 576.6000
# ====== D O N E ====== : 25 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co656-rwl-noaa.txt
# Min : 233 	---> Tree : 6
# Max : 1348 	---> Tree : 19
# Avg : 793.1000
# ====== D O N E ====== : 26 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm015-rwl-noaa.txt
# Min : 135 	---> Tree : 14
# Max : 414 	---> Tree : 2
# Avg : 293.4667
# ====== D O N E ====== : 27 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co072-rwl-noaa.txt
# Min : 106 	---> Tree : 0
# Max : 993 	---> Tree : 8
# Avg : 464.8000
# ====== D O N E ====== : 28 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co071-rwl-noaa.txt
# Min : 130 	---> Tree : 23
# Max : 1331 	---> Tree : 26
# Avg : 445.1071
# ====== D O N E ====== : 29 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm014-rwl-noaa.txt
# Min : 227 	---> Tree : 3
# Max : 534 	---> Tree : 10
# Avg : 363.2857
# ====== D O N E ====== : 30 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az595-rwl-noaa.txt
# Min : 32 	---> Tree : 36
# Max : 178 	---> Tree : 14
# Avg : 80.6000
# ====== D O N E ====== : 31 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az600-rwl-noaa.txt
# Min : 79 	---> Tree : 0
# Max : 178 	---> Tree : 10
# Avg : 120.5714
# ====== D O N E ====== : 32 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az597-rwl-noaa.txt
# Min : 40 	---> Tree : 45
# Max : 144 	---> Tree : 23
# Avg : 75.2586
# ====== D O N E ====== : 33 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az603-rwl-noaa.txt
# Min : 67 	---> Tree : 5
# Max : 144 	---> Tree : 8
# Avg : 89.2667
# ====== D O N E ====== : 34 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca531-rwl-noaa.txt
# Min : 331 	---> Tree : 17
# Max : 962 	---> Tree : 15
# Avg : 513.3600
# ====== D O N E ====== : 35 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca636-rwl-noaa.txt
# Min : 159 	---> Tree : 38
# Max : 1163 	---> Tree : 53
# Avg : 448.7937
# ====== D O N E ====== : 36 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca555-rwl-noaa.txt
# Min : 67 	---> Tree : 18
# Max : 813 	---> Tree : 25
# Avg : 438.5161
# ====== D O N E ====== : 37 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca528-rwl-noaa.txt
# Min : 353 	---> Tree : 13
# Max : 1046 	---> Tree : 0
# Avg : 647.5000
# ====== D O N E ====== : 38 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca637-rwl-noaa.txt
# Min : 55 	---> Tree : 12
# Max : 1096 	---> Tree : 98
# Avg : 430.9912
# ====== D O N E ====== : 39 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca529-rwl-noaa.txt
# Min : 229 	---> Tree : 25
# Max : 1009 	---> Tree : 3
# Avg : 631.6786
# ====== D O N E ====== : 40 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca638-rwl-noaa.txt
# Min : 530 	---> Tree : 4
# Max : 1231 	---> Tree : 9
# Avg : 825.8710
# ====== D O N E ====== : 41 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca530-rwl-noaa.txt
# Min : 230 	---> Tree : 25
# Max : 1034 	---> Tree : 3
# Avg : 545.1379
# ====== D O N E ====== : 42 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca532-rwl-noaa.txt
# Min : 119 	---> Tree : 9
# Max : 939 	---> Tree : 2
# Avg : 600.7500
# ====== D O N E ====== : 43 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi032-rwl-noaa.txt
# Min : 34 	---> Tree : 23
# Max : 81 	---> Tree : 17
# Avg : 52.7143
# ====== D O N E ====== : 44 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co634-rwl-noaa.txt
# Min : 210 	---> Tree : 0
# Max : 258 	---> Tree : 6
# Avg : 240.2500
# ====== D O N E ====== : 45 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca560i-rwl-noaa.txt
# Min : 168 	---> Tree : 0
# Max : 472 	---> Tree : 10
# Avg : 351.2273
# ====== D O N E ====== : 46 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca556n-rwl-noaa.txt
# Min : 185 	---> Tree : 16
# Max : 434 	---> Tree : 9
# Avg : 318.4348
# ====== D O N E ====== : 47 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca560t-rwl-noaa.txt
# Min : 168 	---> Tree : 0
# Max : 472 	---> Tree : 10
# Avg : 351.2273
# ====== D O N E ====== : 48 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy072-rwl-noaa.txt
# Min : 19 	---> Tree : 15
# Max : 206 	---> Tree : 80
# Avg : 113.0932
# ====== D O N E ====== : 49 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca556-rwl-noaa.txt
# Min : 185 	---> Tree : 16
# Max : 434 	---> Tree : 9
# Avg : 318.4348
# ====== D O N E ====== : 50 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca560e-rwl-noaa.txt
# Min : 168 	---> Tree : 0
# Max : 472 	---> Tree : 10
# Avg : 351.2273
# ====== D O N E ====== : 51 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca556t-rwl-noaa.txt
# Min : 185 	---> Tree : 16
# Max : 434 	---> Tree : 9
# Avg : 318.4348
# ====== D O N E ====== : 52 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca556l-rwl-noaa.txt
# Min : 185 	---> Tree : 16
# Max : 434 	---> Tree : 9
# Avg : 318.4348
# ====== D O N E ====== : 53 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca560x-rwl-noaa.txt
# Min : 168 	---> Tree : 0
# Max : 472 	---> Tree : 10
# Avg : 351.2273
# ====== D O N E ====== : 54 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca556e-rwl-noaa.txt
# Min : 185 	---> Tree : 16
# Max : 434 	---> Tree : 9
# Avg : 318.4348
# ====== D O N E ====== : 55 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca560n-rwl-noaa.txt
# Min : 168 	---> Tree : 0
# Max : 472 	---> Tree : 10
# Avg : 351.2273
# ====== D O N E ====== : 56 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca556x-rwl-noaa.txt
# Min : 185 	---> Tree : 16
# Max : 434 	---> Tree : 9
# Avg : 318.4348
# ====== D O N E ====== : 57 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca556i-rwl-noaa.txt
# Min : 185 	---> Tree : 16
# Max : 434 	---> Tree : 9
# Avg : 318.4348
# ====== D O N E ====== : 58 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co546-rwl-noaa.txt
# Min : 132 	---> Tree : 18
# Max : 202 	---> Tree : 9
# Avg : 180.0333
# ====== D O N E ====== : 59 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co563-rwl-noaa.txt
# Min : 225 	---> Tree : 7
# Max : 305 	---> Tree : 46
# Avg : 286.2388
# ====== D O N E ====== : 60 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy051-rwl-noaa.txt
# Min : 48 	---> Tree : 4
# Max : 348 	---> Tree : 19
# Avg : 154.8519
# ====== D O N E ====== : 61 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co536-rwl-noaa.txt
# Min : 109 	---> Tree : 3
# Max : 133 	---> Tree : 18
# Avg : 120.9500
# ====== D O N E ====== : 62 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy048-rwl-noaa.txt
# Min : 92 	---> Tree : 24
# Max : 332 	---> Tree : 18
# Avg : 208.0909
# ====== D O N E ====== : 63 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy035-rwl-noaa.txt
# Min : 53 	---> Tree : 16
# Max : 110 	---> Tree : 10
# Avg : 78.7059
# ====== D O N E ====== : 64 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy036-rwl-noaa.txt
# Min : 31 	---> Tree : 37
# Max : 252 	---> Tree : 6
# Avg : 97.0000
# ====== D O N E ====== : 65 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy047-rwl-noaa.txt
# Min : 70 	---> Tree : 2
# Max : 254 	---> Tree : 1
# Avg : 174.2286
# ====== D O N E ====== : 66 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca580-rwl-noaa.txt
# Min : 88 	---> Tree : 2
# Max : 112 	---> Tree : 0
# Avg : 110.6571
# ====== D O N E ====== : 67 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  or083-rwl-noaa.txt
# Min : 16 	---> Tree : 42
# Max : 111 	---> Tree : 17
# Avg : 55.1163
# ====== D O N E ====== : 68 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca671-rwl-noaa.txt
# Min : 69 	---> Tree : 3
# Max : 401 	---> Tree : 12
# Avg : 188.8387
# ====== D O N E ====== : 69 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca560l-rwl-noaa.txt
# Min : 168 	---> Tree : 0
# Max : 472 	---> Tree : 10
# Avg : 351.2273
# ====== D O N E ====== : 70 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca642-rwl-noaa.txt
# Min : 112 	---> Tree : 15
# Max : 307 	---> Tree : 4
# Avg : 193.7619
# ====== D O N E ====== : 71 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca641-rwl-noaa.txt
# Min : 132 	---> Tree : 10
# Max : 307 	---> Tree : 5
# Avg : 211.4545
# ====== D O N E ====== : 72 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca560-rwl-noaa.txt
# Min : 168 	---> Tree : 0
# Max : 472 	---> Tree : 10
# Avg : 351.2273
# ====== D O N E ====== : 73 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ak200-rwl-noaa.txt
# Min : 71 	---> Tree : 12
# Max : 520 	---> Tree : 84
# Avg : 239.5368
# ====== D O N E ====== : 74 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca643-rwl-noaa.txt
# Min : 68 	---> Tree : 41
# Max : 307 	---> Tree : 3
# Avg : 169.9773
# ====== D O N E ====== : 75 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ak198-rwl-noaa.txt
# Min : 68 	---> Tree : 34
# Max : 400 	---> Tree : 36
# Avg : 228.6190
# ====== D O N E ====== : 76 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca600-rwl-noaa.txt
# Min : 23 	---> Tree : 5
# Max : 169 	---> Tree : 12
# Avg : 78.0000
# ====== D O N E ====== : 77 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  il007-rwl-noaa.txt
# Min : 112 	---> Tree : 15
# Max : 168 	---> Tree : 5
# Avg : 144.2000
# ====== D O N E ====== : 78 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar017-rwl-noaa.txt
# Min : 51 	---> Tree : 2
# Max : 81 	---> Tree : 0
# Avg : 60.2000
# ====== D O N E ====== : 79 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nc8-rwl-noaa.txt
# Min : 58 	---> Tree : 20
# Max : 115 	---> Tree : 30
# Avg : 82.0303
# ====== D O N E ====== : 80 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  il006-rwl-noaa.txt
# Min : 122 	---> Tree : 7
# Max : 243 	---> Tree : 9
# Avg : 178.2500
# ====== D O N E ====== : 81 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  sc003l-rwl-noaa.txt
# Min : 49 	---> Tree : 8
# Max : 276 	---> Tree : 30
# Avg : 117.1818
# ====== D O N E ====== : 82 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar016-rwl-noaa.txt
# Min : 69 	---> Tree : 10
# Max : 108 	---> Tree : 16
# Avg : 89.9500
# ====== D O N E ====== : 83 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mo006-rwl-noaa.txt
# Min : 77 	---> Tree : 13
# Max : 217 	---> Tree : 27
# Avg : 134.2000
# ====== D O N E ====== : 84 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nc3-rwl-noaa.txt
# Min : 38 	---> Tree : 2
# Max : 181 	---> Tree : 7
# Avg : 88.0667
# ====== D O N E ====== : 85 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  sc003-rwl-noaa.txt
# Min : 49 	---> Tree : 8
# Max : 275 	---> Tree : 30
# Avg : 116.6364
# ====== D O N E ====== : 86 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ok038-rwl-noaa.txt
# Min : 67 	---> Tree : 25
# Max : 219 	---> Tree : 33
# Avg : 135.0000
# ====== D O N E ====== : 87 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  sc003e-rwl-noaa.txt
# Min : 49 	---> Tree : 8
# Max : 275 	---> Tree : 30
# Avg : 116.6364
# ====== D O N E ====== : 88 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar067l-rwl-noaa.txt
# Min : 94 	---> Tree : 4
# Max : 214 	---> Tree : 8
# Avg : 152.8000
# ====== D O N E ====== : 89 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ga001-rwl-noaa.txt
# Min : 36 	---> Tree : 33
# Max : 167 	---> Tree : 66
# Avg : 97.6753
# ====== D O N E ====== : 90 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wv033-rwl-noaa.txt
# Min : 101 	---> Tree : 16
# Max : 186 	---> Tree : 11
# Avg : 154.3462
# ====== D O N E ====== : 91 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar004-rwl-noaa.txt
# Min : 82 	---> Tree : 7
# Max : 203 	---> Tree : 3
# Avg : 121.3000
# ====== D O N E ====== : 92 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ga001l-rwl-noaa.txt
# Min : 36 	---> Tree : 33
# Max : 167 	---> Tree : 66
# Avg : 97.0390
# ====== D O N E ====== : 93 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ga001e-rwl-noaa.txt
# Min : 37 	---> Tree : 33
# Max : 168 	---> Tree : 66
# Avg : 98.0260
# ====== D O N E ====== : 94 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar063l-rwl-noaa.txt
# Min : 53 	---> Tree : 22
# Max : 231 	---> Tree : 28
# Avg : 148.4000
# ====== D O N E ====== : 95 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar012-rwl-noaa.txt
# Min : 48 	---> Tree : 2
# Max : 106 	---> Tree : 10
# Avg : 90.2000
# ====== D O N E ====== : 96 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mo038-rwl-noaa.txt
# Min : 102 	---> Tree : 26
# Max : 286 	---> Tree : 38
# Avg : 156.7250
# ====== D O N E ====== : 97 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar063-rwl-noaa.txt
# Min : 53 	---> Tree : 22
# Max : 231 	---> Tree : 28
# Avg : 148.4000
# ====== D O N E ====== : 98 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar067e-rwl-noaa.txt
# Min : 94 	---> Tree : 4
# Max : 214 	---> Tree : 8
# Avg : 152.8000
# ====== D O N E ====== : 99 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar063e-rwl-noaa.txt
# Min : 53 	---> Tree : 22
# Max : 231 	---> Tree : 28
# Avg : 148.4000
# ====== D O N E ====== : 100 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ga018-rwl-noaa.txt
# Min : 116 	---> Tree : 45
# Max : 273 	---> Tree : 21
# Avg : 185.8696
# ====== D O N E ====== : 101 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar030-rwl-noaa.txt
# Min : 60 	---> Tree : 8
# Max : 248 	---> Tree : 9
# Avg : 182.5862
# ====== D O N E ====== : 102 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar006-rwl-noaa.txt
# Min : 58 	---> Tree : 7
# Max : 133 	---> Tree : 5
# Avg : 107.1000
# ====== D O N E ====== : 103 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar069-rwl-noaa.txt
# Min : 90 	---> Tree : 13
# Max : 150 	---> Tree : 6
# Avg : 119.0769
# ====== D O N E ====== : 104 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  tn022e-rwl-noaa.txt
# Min : 109 	---> Tree : 3
# Max : 315 	---> Tree : 20
# Avg : 192.5333
# ====== D O N E ====== : 105 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar027-rwl-noaa.txt
# Min : 109 	---> Tree : 3
# Max : 315 	---> Tree : 42
# Avg : 191.9375
# ====== D O N E ====== : 106 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar027e-rwl-noaa.txt
# Min : 109 	---> Tree : 3
# Max : 315 	---> Tree : 41
# Avg : 197.3409
# ====== D O N E ====== : 107 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar067-rwl-noaa.txt
# Min : 94 	---> Tree : 4
# Max : 214 	---> Tree : 8
# Avg : 152.8000
# ====== D O N E ====== : 108 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  tn022-rwl-noaa.txt
# Min : 106 	---> Tree : 18
# Max : 315 	---> Tree : 20
# Avg : 186.1667
# ====== D O N E ====== : 109 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar069e-rwl-noaa.txt
# Min : 90 	---> Tree : 13
# Max : 150 	---> Tree : 6
# Avg : 119.0769
# ====== D O N E ====== : 110 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  tn022l-rwl-noaa.txt
# Min : 109 	---> Tree : 3
# Max : 315 	---> Tree : 20
# Avg : 192.5333
# ====== D O N E ====== : 111 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar036-rwl-noaa.txt
# Min : 85 	---> Tree : 13
# Max : 195 	---> Tree : 3
# Avg : 123.5926
# ====== D O N E ====== : 112 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar069l-rwl-noaa.txt
# Min : 90 	---> Tree : 13
# Max : 150 	---> Tree : 6
# Avg : 119.0769
# ====== D O N E ====== : 113 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ok031l-rwl-noaa.txt
# Min : 128 	---> Tree : 6
# Max : 299 	---> Tree : 3
# Avg : 195.9038
# ====== D O N E ====== : 114 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar027l-rwl-noaa.txt
# Min : 109 	---> Tree : 3
# Max : 315 	---> Tree : 41
# Avg : 197.3409
# ====== D O N E ====== : 115 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar033-rwl-noaa.txt
# Min : 124 	---> Tree : 15
# Max : 239 	---> Tree : 26
# Avg : 190.1333
# ====== D O N E ====== : 116 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar076-rwl-noaa.txt
# Min : 50 	---> Tree : 12
# Max : 96 	---> Tree : 11
# Avg : 66.8824
# ====== D O N E ====== : 117 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ok034-rwl-noaa.txt
# Min : 38 	---> Tree : 0
# Max : 282 	---> Tree : 3
# Avg : 124.3585
# ====== D O N E ====== : 118 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  tn032-rwl-noaa.txt
# Min : 51 	---> Tree : 31
# Max : 202 	---> Tree : 17
# Avg : 115.9000
# ====== D O N E ====== : 119 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar078-rwl-noaa.txt
# Min : 55 	---> Tree : 5
# Max : 63 	---> Tree : 1
# Avg : 60.3077
# ====== D O N E ====== : 120 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar083-rwl-noaa.txt
# Min : 26 	---> Tree : 32
# Max : 99 	---> Tree : 45
# Avg : 59.5106
# ====== D O N E ====== : 121 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  tn028-rwl-noaa.txt
# Min : 51 	---> Tree : 31
# Max : 202 	---> Tree : 17
# Avg : 115.9000
# ====== D O N E ====== : 122 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ok037-rwl-noaa.txt
# Min : 49 	---> Tree : 1
# Max : 64 	---> Tree : 8
# Avg : 56.6875
# ====== D O N E ====== : 123 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ok031-rwl-noaa.txt
# Min : 128 	---> Tree : 6
# Max : 299 	---> Tree : 3
# Avg : 195.9038
# ====== D O N E ====== : 124 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mo045-rwl-noaa.txt
# Min : 72 	---> Tree : 66
# Max : 250 	---> Tree : 36
# Avg : 126.5566
# ====== D O N E ====== : 125 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ok036-rwl-noaa.txt
# Min : 32 	---> Tree : 13
# Max : 42 	---> Tree : 6
# Avg : 38.2143
# ====== D O N E ====== : 126 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar082-rwl-noaa.txt
# Min : 62 	---> Tree : 14
# Max : 86 	---> Tree : 18
# Avg : 78.8636
# ====== D O N E ====== : 127 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar077-rwl-noaa.txt
# Min : 50 	---> Tree : 3
# Max : 68 	---> Tree : 6
# Avg : 61.5652
# ====== D O N E ====== : 128 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ok031e-rwl-noaa.txt
# Min : 128 	---> Tree : 6
# Max : 299 	---> Tree : 3
# Avg : 195.9038
# ====== D O N E ====== : 129 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar074-rwl-noaa.txt
# Min : 73 	---> Tree : 2
# Max : 211 	---> Tree : 18
# Avg : 149.7308
# ====== D O N E ====== : 130 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mo075-rwl-noaa.txt
# Min : 37 	---> Tree : 130
# Max : 189 	---> Tree : 65
# Avg : 82.4217
# ====== D O N E ====== : 131 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar080-rwl-noaa.txt
# Min : 35 	---> Tree : 7
# Max : 70 	---> Tree : 0
# Avg : 59.2222
# ====== D O N E ====== : 132 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar081-rwl-noaa.txt
# Min : 53 	---> Tree : 20
# Max : 122 	---> Tree : 1
# Avg : 73.7500
# ====== D O N E ====== : 133 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ar079-rwl-noaa.txt
# Min : 46 	---> Tree : 2
# Max : 66 	---> Tree : 15
# Avg : 58.3750
# ====== D O N E ====== : 134 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mo051-rwl-noaa.txt
# Min : 36 	---> Tree : 3
# Max : 196 	---> Tree : 53
# Avg : 83.5402
# ====== D O N E ====== : 135 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm545i-rwl-noaa.txt
# Min : 100 	---> Tree : 2
# Max : 220 	---> Tree : 0
# Avg : 149.5000
# ====== D O N E ====== : 136 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm545x-rwl-noaa.txt
# Min : 99 	---> Tree : 2
# Max : 219 	---> Tree : 0
# Avg : 148.5000
# ====== D O N E ====== : 137 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm545n-rwl-noaa.txt
# Min : 100 	---> Tree : 2
# Max : 220 	---> Tree : 0
# Avg : 149.5000
# ====== D O N E ====== : 138 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az071-rwl-noaa.txt
# Min : 80 	---> Tree : 0
# Max : 270 	---> Tree : 6
# Avg : 214.0000
# ====== D O N E ====== : 139 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut533-rwl-noaa.txt
# Min : 238 	---> Tree : 18
# Max : 700 	---> Tree : 4
# Avg : 382.2364
# ====== D O N E ====== : 140 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut534-rwl-noaa.txt
# Min : 63 	---> Tree : 15
# Max : 578 	---> Tree : 45
# Avg : 283.4038
# ====== D O N E ====== : 141 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az605-rwl-noaa.txt
# Min : 48 	---> Tree : 6
# Max : 340 	---> Tree : 37
# Avg : 218.4889
# ====== D O N E ====== : 142 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm545t-rwl-noaa.txt
# Min : 99 	---> Tree : 2
# Max : 219 	---> Tree : 0
# Avg : 148.5000
# ====== D O N E ====== : 143 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co692l-rwl-noaa.txt
# Min : 103 	---> Tree : 16
# Max : 420 	---> Tree : 13
# Avg : 233.7273
# ====== D O N E ====== : 144 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm545e-rwl-noaa.txt
# Min : 100 	---> Tree : 2
# Max : 220 	---> Tree : 0
# Avg : 149.5000
# ====== D O N E ====== : 145 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm545d-rwl-noaa.txt
# Min : 99 	---> Tree : 2
# Max : 219 	---> Tree : 0
# Avg : 148.5000
# ====== D O N E ====== : 146 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co693e-rwl-noaa.txt
# Min : 90 	---> Tree : 0
# Max : 592 	---> Tree : 16
# Avg : 322.9062
# ====== D O N E ====== : 147 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co693-rwl-noaa.txt
# Min : 44 	---> Tree : 50
# Max : 650 	---> Tree : 28
# Avg : 344.4405
# ====== D O N E ====== : 148 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm035-rwl-noaa.txt
# Min : 142 	---> Tree : 6
# Max : 484 	---> Tree : 8
# Avg : 281.8250
# ====== D O N E ====== : 149 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co692-rwl-noaa.txt
# Min : 103 	---> Tree : 16
# Max : 466 	---> Tree : 49
# Avg : 300.3514
# ====== D O N E ====== : 150 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm545-rwl-noaa.txt
# Min : 100 	---> Tree : 2
# Max : 220 	---> Tree : 0
# Avg : 149.5000
# ====== D O N E ====== : 151 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm048-rwl-noaa.txt
# Min : 118 	---> Tree : 36
# Max : 310 	---> Tree : 28
# Avg : 170.8250
# ====== D O N E ====== : 152 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co692e-rwl-noaa.txt
# Min : 103 	---> Tree : 16
# Max : 420 	---> Tree : 13
# Avg : 233.7273
# ====== D O N E ====== : 153 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co693l-rwl-noaa.txt
# Min : 90 	---> Tree : 0
# Max : 592 	---> Tree : 16
# Avg : 322.9062
# ====== D O N E ====== : 154 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm545l-rwl-noaa.txt
# Min : 100 	---> Tree : 2
# Max : 220 	---> Tree : 0
# Avg : 149.5000
# ====== D O N E ====== : 155 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az084-rwl-noaa.txt
# Min : 159 	---> Tree : 27
# Max : 406 	---> Tree : 4
# Avg : 288.1389
# ====== D O N E ====== : 156 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az101-rwl-noaa.txt
# Min : 134 	---> Tree : 27
# Max : 440 	---> Tree : 20
# Avg : 233.6000
# ====== D O N E ====== : 157 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az570-rwl-noaa.txt
# Min : 52 	---> Tree : 17
# Max : 702 	---> Tree : 93
# Avg : 239.2083
# ====== D O N E ====== : 158 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az099-rwl-noaa.txt
# Min : 144 	---> Tree : 16
# Max : 288 	---> Tree : 9
# Avg : 234.5333
# ====== D O N E ====== : 159 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az139-rwl-noaa.txt
# Min : 136 	---> Tree : 0
# Max : 346 	---> Tree : 5
# Avg : 260.7692
# ====== D O N E ====== : 160 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az578-rwl-noaa.txt
# Min : 53 	---> Tree : 49
# Max : 592 	---> Tree : 104
# Avg : 281.4597
# ====== D O N E ====== : 161 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm053-rwl-noaa.txt
# Min : 107 	---> Tree : 37
# Max : 349 	---> Tree : 18
# Avg : 247.3000
# ====== D O N E ====== : 162 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm034-rwl-noaa.txt
# Min : 184 	---> Tree : 8
# Max : 312 	---> Tree : 26
# Avg : 249.6389
# ====== D O N E ====== : 163 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm023-rwl-noaa.txt
# Min : 201 	---> Tree : 3
# Max : 398 	---> Tree : 14
# Avg : 258.6667
# ====== D O N E ====== : 164 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm038-rwl-noaa.txt
# Min : 174 	---> Tree : 1
# Max : 418 	---> Tree : 28
# Avg : 283.8621
# ====== D O N E ====== : 165 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm613-rwl-noaa.txt
# Min : 52 	---> Tree : 18
# Max : 721 	---> Tree : 0
# Avg : 179.9748
# ====== D O N E ====== : 166 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm032-rwl-noaa.txt
# Min : 88 	---> Tree : 1
# Max : 336 	---> Tree : 24
# Avg : 238.2353
# ====== D O N E ====== : 167 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm027-rwl-noaa.txt
# Min : 84 	---> Tree : 9
# Max : 330 	---> Tree : 7
# Avg : 219.3750
# ====== D O N E ====== : 168 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm051-rwl-noaa.txt
# Min : 136 	---> Tree : 16
# Max : 291 	---> Tree : 21
# Avg : 225.4375
# ====== D O N E ====== : 169 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut543-rwl-noaa.txt
# Min : 50 	---> Tree : 24
# Max : 696 	---> Tree : 129
# Avg : 294.0473
# ====== D O N E ====== : 170 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az081-rwl-noaa.txt
# Min : 167 	---> Tree : 27
# Max : 372 	---> Tree : 43
# Avg : 277.9773
# ====== D O N E ====== : 171 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az091-rwl-noaa.txt
# Min : 121 	---> Tree : 21
# Max : 285 	---> Tree : 23
# Avg : 220.8333
# ====== D O N E ====== : 172 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm055-rwl-noaa.txt
# Min : 170 	---> Tree : 15
# Max : 374 	---> Tree : 0
# Avg : 268.6364
# ====== D O N E ====== : 173 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az106-rwl-noaa.txt
# Min : 253 	---> Tree : 0
# Max : 529 	---> Tree : 13
# Avg : 326.7000
# ====== D O N E ====== : 174 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm043-rwl-noaa.txt
# Min : 136 	---> Tree : 25
# Max : 316 	---> Tree : 15
# Avg : 256.7407
# ====== D O N E ====== : 175 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm040-rwl-noaa.txt
# Min : 117 	---> Tree : 11
# Max : 395 	---> Tree : 24
# Avg : 205.4000
# ====== D O N E ====== : 176 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az086-rwl-noaa.txt
# Min : 186 	---> Tree : 21
# Max : 606 	---> Tree : 20
# Avg : 410.4643
# ====== D O N E ====== : 177 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut024-rwl-noaa.txt
# Min : 254 	---> Tree : 4
# Max : 696 	---> Tree : 1
# Avg : 396.7000
# ====== D O N E ====== : 178 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut022-rwl-noaa.txt
# Min : 117 	---> Tree : 5
# Max : 499 	---> Tree : 3
# Avg : 361.1538
# ====== D O N E ====== : 179 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm028-rwl-noaa.txt
# Min : 121 	---> Tree : 16
# Max : 291 	---> Tree : 4
# Avg : 215.5500
# ====== D O N E ====== : 180 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut020-rwl-noaa.txt
# Min : 231 	---> Tree : 24
# Max : 528 	---> Tree : 17
# Avg : 407.5357
# ====== D O N E ====== : 181 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az078-rwl-noaa.txt
# Min : 113 	---> Tree : 3
# Max : 278 	---> Tree : 18
# Avg : 175.1364
# ====== D O N E ====== : 182 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az517-rwl-noaa.txt
# Min : 225 	---> Tree : 6
# Max : 340 	---> Tree : 17
# Avg : 291.6800
# ====== D O N E ====== : 183 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut527-rwl-noaa.txt
# Min : 113 	---> Tree : 1
# Max : 1116 	---> Tree : 12
# Avg : 489.7742
# ====== D O N E ====== : 184 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az102-rwl-noaa.txt
# Min : 163 	---> Tree : 26
# Max : 562 	---> Tree : 0
# Avg : 414.3000
# ====== D O N E ====== : 185 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm037-rwl-noaa.txt
# Min : 125 	---> Tree : 20
# Max : 318 	---> Tree : 8
# Avg : 192.2083
# ====== D O N E ====== : 186 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut526-rwl-noaa.txt
# Min : 215 	---> Tree : 10
# Max : 963 	---> Tree : 6
# Avg : 451.0500
# ====== D O N E ====== : 187 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm030-rwl-noaa.txt
# Min : 198 	---> Tree : 30
# Max : 563 	---> Tree : 19
# Avg : 344.0882
# ====== D O N E ====== : 188 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nv503-rwl-noaa.txt
# Min : 106 	---> Tree : 7
# Max : 352 	---> Tree : 10
# Avg : 241.2500
# ====== D O N E ====== : 189 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co043-rwl-noaa.txt
# Min : 126 	---> Tree : 12
# Max : 436 	---> Tree : 8
# Avg : 315.5238
# ====== D O N E ====== : 190 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az518-rwl-noaa.txt
# Min : 123 	---> Tree : 0
# Max : 342 	---> Tree : 20
# Avg : 186.0333
# ====== D O N E ====== : 191 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az516-rwl-noaa.txt
# Min : 95 	---> Tree : 10
# Max : 278 	---> Tree : 3
# Avg : 159.2105
# ====== D O N E ====== : 192 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut525-rwl-noaa.txt
# Min : 114 	---> Tree : 5
# Max : 619 	---> Tree : 69
# Avg : 360.3973
# ====== D O N E ====== : 193 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nv505-rwl-noaa.txt
# Min : 96 	---> Tree : 22
# Max : 373 	---> Tree : 27
# Avg : 223.1786
# ====== D O N E ====== : 194 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm050-rwl-noaa.txt
# Min : 96 	---> Tree : 16
# Max : 337 	---> Tree : 26
# Avg : 163.3158
# ====== D O N E ====== : 195 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm564-rwl-noaa.txt
# Min : 253 	---> Tree : 0
# Max : 586 	---> Tree : 18
# Avg : 335.7500
# ====== D O N E ====== : 196 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut516-rwl-noaa.txt
# Min : 177 	---> Tree : 9
# Max : 447 	---> Tree : 10
# Avg : 343.5714
# ====== D O N E ====== : 197 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co067-rwl-noaa.txt
# Min : 119 	---> Tree : 0
# Max : 649 	---> Tree : 19
# Avg : 327.1290
# ====== D O N E ====== : 198 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az144-rwl-noaa.txt
# Min : 147 	---> Tree : 22
# Max : 491 	---> Tree : 24
# Avg : 270.8000
# ====== D O N E ====== : 199 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut517-rwl-noaa.txt
# Min : 131 	---> Tree : 29
# Max : 523 	---> Tree : 18
# Avg : 338.9394
# ====== D O N E ====== : 200 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm119-rwl-noaa.txt
# Min : 45 	---> Tree : 38
# Max : 329 	---> Tree : 19
# Avg : 181.0476
# ====== D O N E ====== : 201 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut521-rwl-noaa.txt
# Min : 64 	---> Tree : 3
# Max : 412 	---> Tree : 10
# Avg : 243.6667
# ====== D O N E ====== : 202 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm547-rwl-noaa.txt
# Min : 64 	---> Tree : 18
# Max : 249 	---> Tree : 37
# Avg : 130.4286
# ====== D O N E ====== : 203 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm568-rwl-noaa.txt
# Min : 164 	---> Tree : 13
# Max : 327 	---> Tree : 4
# Avg : 258.7917
# ====== D O N E ====== : 204 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut522-rwl-noaa.txt
# Min : 152 	---> Tree : 6
# Max : 592 	---> Tree : 14
# Avg : 289.7368
# ====== D O N E ====== : 205 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut520-rwl-noaa.txt
# Min : 148 	---> Tree : 19
# Max : 435 	---> Tree : 11
# Avg : 293.8462
# ====== D O N E ====== : 206 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm546-rwl-noaa.txt
# Min : 96 	---> Tree : 27
# Max : 218 	---> Tree : 6
# Avg : 163.7931
# ====== D O N E ====== : 207 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az563-rwl-noaa.txt
# Min : 67 	---> Tree : 1
# Max : 464 	---> Tree : 4
# Avg : 282.9615
# ====== D O N E ====== : 208 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut518-rwl-noaa.txt
# Min : 190 	---> Tree : 8
# Max : 494 	---> Tree : 3
# Avg : 298.1250
# ====== D O N E ====== : 209 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut562-rwl-noaa.txt
# Min : 48 	---> Tree : 2
# Max : 128 	---> Tree : 0
# Avg : 109.0000
# ====== D O N E ====== : 210 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az615-rwl-noaa.txt
# Min : 43 	---> Tree : 0
# Max : 96 	---> Tree : 5
# Avg : 71.0000
# ====== D O N E ====== : 211 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut560-rwl-noaa.txt
# Min : 62 	---> Tree : 4
# Max : 273 	---> Tree : 29
# Avg : 157.2581
# ====== D O N E ====== : 212 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm031-rwl-noaa.txt
# Min : 139 	---> Tree : 9
# Max : 497 	---> Tree : 27
# Avg : 340.0208
# ====== D O N E ====== : 213 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm624-rwl-noaa.txt
# Min : 34 	---> Tree : 22
# Max : 91 	---> Tree : 29
# Avg : 67.1000
# ====== D O N E ====== : 214 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az616-rwl-noaa.txt
# Min : 51 	---> Tree : 11
# Max : 137 	---> Tree : 27
# Avg : 91.0000
# ====== D O N E ====== : 215 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm623-rwl-noaa.txt
# Min : 58 	---> Tree : 19
# Max : 168 	---> Tree : 4
# Avg : 115.7692
# ====== D O N E ====== : 216 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut018-rwl-noaa.txt
# Min : 316 	---> Tree : 1
# Max : 485 	---> Tree : 2
# Avg : 377.2273
# ====== D O N E ====== : 217 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az613-rwl-noaa.txt
# Min : 53 	---> Tree : 16
# Max : 88 	---> Tree : 3
# Avg : 83.1176
# ====== D O N E ====== : 218 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co686-rwl-noaa.txt
# Min : 48 	---> Tree : 11
# Max : 128 	---> Tree : 0
# Avg : 105.2000
# ====== D O N E ====== : 219 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm625-rwl-noaa.txt
# Min : 55 	---> Tree : 11
# Max : 168 	---> Tree : 0
# Avg : 113.3704
# ====== D O N E ====== : 220 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut559-rwl-noaa.txt
# Min : 32 	---> Tree : 5
# Max : 128 	---> Tree : 0
# Avg : 99.3077
# ====== D O N E ====== : 221 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az041-rwl-noaa.txt
# Min : 118 	---> Tree : 2
# Max : 268 	---> Tree : 8
# Avg : 169.3182
# ====== D O N E ====== : 222 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az614-rwl-noaa.txt
# Min : 24 	---> Tree : 1
# Max : 127 	---> Tree : 8
# Avg : 65.9333
# ====== D O N E ====== : 223 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm006-rwl-noaa.txt
# Min : 137 	---> Tree : 4
# Max : 297 	---> Tree : 7
# Avg : 212.5000
# ====== D O N E ====== : 224 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm118-rwl-noaa.txt
# Min : 132 	---> Tree : 7
# Max : 420 	---> Tree : 14
# Avg : 266.1111
# ====== D O N E ====== : 225 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az129-rwl-noaa.txt
# Min : 103 	---> Tree : 17
# Max : 496 	---> Tree : 20
# Avg : 294.4444
# ====== D O N E ====== : 226 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co049-rwl-noaa.txt
# Min : 106 	---> Tree : 18
# Max : 326 	---> Tree : 0
# Avg : 238.5500
# ====== D O N E ====== : 227 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co063-rwl-noaa.txt
# Min : 131 	---> Tree : 12
# Max : 538 	---> Tree : 2
# Avg : 367.3846
# ====== D O N E ====== : 228 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm111-rwl-noaa.txt
# Min : 103 	---> Tree : 19
# Max : 323 	---> Tree : 10
# Avg : 219.9722
# ====== D O N E ====== : 229 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm001-rwl-noaa.txt
# Min : 295 	---> Tree : 0
# Max : 430 	---> Tree : 2
# Avg : 329.0000
# ====== D O N E ====== : 230 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az030-rwl-noaa.txt
# Min : 51 	---> Tree : 12
# Max : 304 	---> Tree : 6
# Avg : 195.7692
# ====== D O N E ====== : 231 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm578-rwl-noaa.txt
# Min : 123 	---> Tree : 12
# Max : 359 	---> Tree : 25
# Avg : 211.2188
# ====== D O N E ====== : 232 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az066-rwl-noaa.txt
# Min : 136 	---> Tree : 50
# Max : 589 	---> Tree : 0
# Avg : 370.8654
# ====== D O N E ====== : 233 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az029-rwl-noaa.txt
# Min : 106 	---> Tree : 16
# Max : 408 	---> Tree : 6
# Avg : 223.0000
# ====== D O N E ====== : 234 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az104-rwl-noaa.txt
# Min : 162 	---> Tree : 0
# Max : 427 	---> Tree : 8
# Avg : 292.0556
# ====== D O N E ====== : 235 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co661-rwl-noaa.txt
# Min : 79 	---> Tree : 5
# Max : 390 	---> Tree : 24
# Avg : 195.1842
# ====== D O N E ====== : 236 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm548-rwl-noaa.txt
# Min : 92 	---> Tree : 13
# Max : 388 	---> Tree : 21
# Avg : 233.4545
# ====== D O N E ====== : 237 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co638-rwl-noaa.txt
# Min : 73 	---> Tree : 2
# Max : 395 	---> Tree : 34
# Avg : 197.5500
# ====== D O N E ====== : 238 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az047-rwl-noaa.txt
# Min : 138 	---> Tree : 2
# Max : 553 	---> Tree : 18
# Avg : 297.2632
# ====== D O N E ====== : 239 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co605-rwl-noaa.txt
# Min : 208 	---> Tree : 29
# Max : 619 	---> Tree : 10
# Avg : 422.9434
# ====== D O N E ====== : 240 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co637-rwl-noaa.txt
# Min : 67 	---> Tree : 31
# Max : 528 	---> Tree : 2
# Avg : 253.5263
# ====== D O N E ====== : 241 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az044-rwl-noaa.txt
# Min : 177 	---> Tree : 11
# Max : 380 	---> Tree : 0
# Avg : 257.0833
# ====== D O N E ====== : 242 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co664-rwl-noaa.txt
# Min : 62 	---> Tree : 63
# Max : 619 	---> Tree : 10
# Avg : 360.9859
# ====== D O N E ====== : 243 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co582-rwl-noaa.txt
# Min : 113 	---> Tree : 26
# Max : 432 	---> Tree : 21
# Avg : 282.3333
# ====== D O N E ====== : 244 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co600-rwl-noaa.txt
# Min : 206 	---> Tree : 28
# Max : 466 	---> Tree : 16
# Avg : 353.1750
# ====== D O N E ====== : 245 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co660-rwl-noaa.txt
# Min : 57 	---> Tree : 46
# Max : 528 	---> Tree : 2
# Avg : 232.5490
# ====== D O N E ====== : 246 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm576-rwl-noaa.txt
# Min : 82 	---> Tree : 18
# Max : 374 	---> Tree : 13
# Avg : 231.4615
# ====== D O N E ====== : 247 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az032-rwl-noaa.txt
# Min : 106 	---> Tree : 16
# Max : 408 	---> Tree : 6
# Avg : 223.0000
# ====== D O N E ====== : 248 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co595-rwl-noaa.txt
# Min : 78 	---> Tree : 32
# Max : 786 	---> Tree : 4
# Avg : 413.5758
# ====== D O N E ====== : 249 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co616-rwl-noaa.txt
# Min : 153 	---> Tree : 37
# Max : 687 	---> Tree : 40
# Avg : 391.8980
# ====== D O N E ====== : 250 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co670-rwl-noaa.txt
# Min : 83 	---> Tree : 20
# Max : 417 	---> Tree : 26
# Avg : 254.2857
# ====== D O N E ====== : 251 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co673-rwl-noaa.txt
# Min : 68 	---> Tree : 40
# Max : 877 	---> Tree : 2
# Avg : 316.6212
# ====== D O N E ====== : 252 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co636-rwl-noaa.txt
# Min : 92 	---> Tree : 14
# Max : 372 	---> Tree : 27
# Avg : 234.5625
# ====== D O N E ====== : 253 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co615-rwl-noaa.txt
# Min : 220 	---> Tree : 23
# Max : 877 	---> Tree : 0
# Avg : 384.6471
# ====== D O N E ====== : 254 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co648-rwl-noaa.txt
# Min : 49 	---> Tree : 59
# Max : 671 	---> Tree : 32
# Avg : 348.6812
# ====== D O N E ====== : 255 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm581-rwl-noaa.txt
# Min : 116 	---> Tree : 42
# Max : 461 	---> Tree : 39
# Avg : 285.6222
# ====== D O N E ====== : 256 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co610-rwl-noaa.txt
# Min : 111 	---> Tree : 30
# Max : 641 	---> Tree : 49
# Avg : 304.4262
# ====== D O N E ====== : 257 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co614-rwl-noaa.txt
# Min : 136 	---> Tree : 31
# Max : 466 	---> Tree : 16
# Avg : 282.5455
# ====== D O N E ====== : 258 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co579-rwl-noaa.txt
# Min : 145 	---> Tree : 44
# Max : 681 	---> Tree : 34
# Avg : 393.5763
# ====== D O N E ====== : 259 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut524-rwl-noaa.txt
# Min : 118 	---> Tree : 34
# Max : 626 	---> Tree : 29
# Avg : 329.5000
# ====== D O N E ====== : 260 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co612-rwl-noaa.txt
# Min : 203 	---> Tree : 36
# Max : 557 	---> Tree : 38
# Avg : 382.1091
# ====== D O N E ====== : 261 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co618-rwl-noaa.txt
# Min : 131 	---> Tree : 18
# Max : 446 	---> Tree : 19
# Avg : 274.3514
# ====== D O N E ====== : 262 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co584-rwl-noaa.txt
# Min : 163 	---> Tree : 27
# Max : 647 	---> Tree : 28
# Avg : 393.9412
# ====== D O N E ====== : 263 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co629-rwl-noaa.txt
# Min : 195 	---> Tree : 26
# Max : 706 	---> Tree : 10
# Avg : 398.8852
# ====== D O N E ====== : 264 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co621-rwl-noaa.txt
# Min : 152 	---> Tree : 18
# Max : 650 	---> Tree : 27
# Avg : 422.4516
# ====== D O N E ====== : 265 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co626-rwl-noaa.txt
# Min : 189 	---> Tree : 14
# Max : 514 	---> Tree : 12
# Avg : 345.8125
# ====== D O N E ====== : 266 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co583-rwl-noaa.txt
# Min : 94 	---> Tree : 29
# Max : 593 	---> Tree : 12
# Avg : 345.7250
# ====== D O N E ====== : 267 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co674-rwl-noaa.txt
# Min : 44 	---> Tree : 50
# Max : 650 	---> Tree : 28
# Avg : 357.6923
# ====== D O N E ====== : 268 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co640-rwl-noaa.txt
# Min : 102 	---> Tree : 27
# Max : 428 	---> Tree : 15
# Avg : 251.6786
# ====== D O N E ====== : 269 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co676-rwl-noaa.txt
# Min : 85 	---> Tree : 72
# Max : 706 	---> Tree : 10
# Avg : 317.9623
# ====== D O N E ====== : 270 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co677-rwl-noaa.txt
# Min : 125 	---> Tree : 69
# Max : 858 	---> Tree : 35
# Avg : 380.0854
# ====== D O N E ====== : 271 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co571-rwl-noaa.txt
# Min : 58 	---> Tree : 3
# Max : 162 	---> Tree : 4
# Avg : 100.5000
# ====== D O N E ====== : 272 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co649-rwl-noaa.txt
# Min : 94 	---> Tree : 51
# Max : 593 	---> Tree : 34
# Avg : 301.2742
# ====== D O N E ====== : 273 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co631-rwl-noaa.txt
# Min : 206 	---> Tree : 37
# Max : 858 	---> Tree : 35
# Avg : 471.6200
# ====== D O N E ====== : 274 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co567-rwl-noaa.txt
# Min : 90 	---> Tree : 16
# Max : 256 	---> Tree : 8
# Avg : 158.8824
# ====== D O N E ====== : 275 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co650-rwl-noaa.txt
# Min : 142 	---> Tree : 57
# Max : 858 	---> Tree : 35
# Avg : 423.6515
# ====== D O N E ====== : 276 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ms004e-rwl-noaa.txt
# Min : 44 	---> Tree : 17
# Max : 107 	---> Tree : 2
# Avg : 65.6552
# ====== D O N E ====== : 277 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl010-rwl-noaa.txt
# Min : 1 	---> Tree : 114
# Max : 243 	---> Tree : 76
# Avg : 65.7181
# ====== D O N E ====== : 278 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ms004-rwl-noaa.txt
# Min : 44 	---> Tree : 18
# Max : 107 	---> Tree : 2
# Avg : 66.7333
# ====== D O N E ====== : 279 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ms004l-rwl-noaa.txt
# Min : 44 	---> Tree : 17
# Max : 107 	---> Tree : 2
# Avg : 65.6667
# ====== D O N E ====== : 280 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut547-rwl-noaa.txt
# Min : 98 	---> Tree : 13
# Max : 615 	---> Tree : 2
# Avg : 233.0476
# ====== D O N E ====== : 281 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ut552-rwl-noaa.txt
# Min : 56 	---> Tree : 8
# Max : 259 	---> Tree : 0
# Avg : 161.4615
# ====== D O N E ====== : 282 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  id020-rwl-noaa.txt
# Min : 59 	---> Tree : 45
# Max : 1157 	---> Tree : 6
# Avg : 380.9643
# ====== D O N E ====== : 283 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy026-rwl-noaa.txt
# Min : 89 	---> Tree : 2
# Max : 520 	---> Tree : 14
# Avg : 357.6000
# ====== D O N E ====== : 284 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mt001-rwl-noaa.txt
# Min : 55 	---> Tree : 13
# Max : 656 	---> Tree : 2
# Avg : 379.8571
# ====== D O N E ====== : 285 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm598-rwl-noaa.txt
# Min : 41 	---> Tree : 80
# Max : 418 	---> Tree : 125
# Avg : 161.6208
# ====== D O N E ====== : 286 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy006-rwl-noaa.txt
# Min : 157 	---> Tree : 48
# Max : 573 	---> Tree : 44
# Avg : 316.3469
# ====== D O N E ====== : 287 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy056-rwl-noaa.txt
# Min : 271 	---> Tree : 14
# Max : 513 	---> Tree : 3
# Avg : 389.6000
# ====== D O N E ====== : 288 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy053-rwl-noaa.txt
# Min : 261 	---> Tree : 11
# Max : 576 	---> Tree : 10
# Avg : 392.2000
# ====== D O N E ====== : 289 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca639-rwl-noaa.txt
# Min : 133 	---> Tree : 9
# Max : 996 	---> Tree : 2
# Avg : 385.9333
# ====== D O N E ====== : 290 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mt004-rwl-noaa.txt
# Min : 121 	---> Tree : 20
# Max : 545 	---> Tree : 21
# Avg : 258.3182
# ====== D O N E ====== : 291 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy054-rwl-noaa.txt
# Min : 187 	---> Tree : 4
# Max : 497 	---> Tree : 1
# Avg : 310.5455
# ====== D O N E ====== : 292 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  co561-rwl-noaa.txt
# Min : 112 	---> Tree : 12
# Max : 512 	---> Tree : 0
# Avg : 195.1765
# ====== D O N E ====== : 293 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy065-rwl-noaa.txt
# Min : 149 	---> Tree : 2
# Max : 788 	---> Tree : 8
# Avg : 448.3333
# ====== D O N E ====== : 294 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy038-rwl-noaa.txt
# Min : 126 	---> Tree : 2
# Max : 634 	---> Tree : 29
# Avg : 345.4000
# ====== D O N E ====== : 295 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca633-rwl-noaa.txt
# Min : 97 	---> Tree : 61
# Max : 1059 	---> Tree : 7
# Avg : 447.6774
# ====== D O N E ====== : 296 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nv511-rwl-noaa.txt
# Min : 192 	---> Tree : 8
# Max : 682 	---> Tree : 25
# Avg : 432.9286
# ====== D O N E ====== : 297 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wy049-rwl-noaa.txt
# ...
# Avg : 82.6207
# ====== D O N E ====== : 459 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl019l-rwl-noaa.txt
# Min : 44 	---> Tree : 48
# Max : 98 	---> Tree : 30
# Avg : 86.8167
# ====== D O N E ====== : 460 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl017l-rwl-noaa.txt
# Min : 6 	---> Tree : 28
# Max : 79 	---> Tree : 5
# Avg : 68.6333
# ====== D O N E ====== : 461 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl020e-rwl-noaa.txt
# Min : 18 	---> Tree : 4
# Max : 117 	---> Tree : 52
# Avg : 85.6500
# ====== D O N E ====== : 462 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl018l-rwl-noaa.txt
# Min : 38 	---> Tree : 28
# Max : 101 	---> Tree : 13
# Avg : 77.6250
# ====== D O N E ====== : 463 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl019-rwl-noaa.txt
# Min : 44 	---> Tree : 48
# Max : 98 	---> Tree : 30
# Avg : 87.3167
# ====== D O N E ====== : 464 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl017e-rwl-noaa.txt
# Min : 6 	---> Tree : 28
# Max : 79 	---> Tree : 5
# Avg : 68.8333
# ====== D O N E ====== : 465 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl017-rwl-noaa.txt
# Min : 6 	---> Tree : 28
# Max : 79 	---> Tree : 5
# Avg : 68.8333
# ====== D O N E ====== : 466 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl020-rwl-noaa.txt
# Min : 18 	---> Tree : 4
# Max : 117 	---> Tree : 52
# Avg : 85.6500
# ====== D O N E ====== : 467 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl015-rwl-noaa.txt
# Min : 7 	---> Tree : 15
# Max : 110 	---> Tree : 54
# Avg : 82.6379
# ====== D O N E ====== : 468 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl018-rwl-noaa.txt
# Min : 39 	---> Tree : 28
# Max : 101 	---> Tree : 13
# Avg : 77.6875
# ====== D O N E ====== : 469 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl021l-rwl-noaa.txt
# Min : 34 	---> Tree : 7
# Max : 210 	---> Tree : 29
# Avg : 81.0357
# ====== D O N E ====== : 470 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl021e-rwl-noaa.txt
# Min : 34 	---> Tree : 7
# Max : 210 	---> Tree : 29
# Avg : 81.1786
# ====== D O N E ====== : 471 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl021-rwl-noaa.txt
# Min : 34 	---> Tree : 7
# Max : 210 	---> Tree : 29
# Avg : 81.1786
# ====== D O N E ====== : 472 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  fl020l-rwl-noaa.txt
# Min : 18 	---> Tree : 4
# Max : 117 	---> Tree : 52
# Avg : 85.3333
# ====== D O N E ====== : 473 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  va020-rwl-noaa.txt
# Min : 43 	---> Tree : 2
# Max : 172 	---> Tree : 19
# Avg : 114.1053
# ====== D O N E ====== : 474 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  va042-rwl-noaa.txt
# Min : 70 	---> Tree : 17
# Max : 101 	---> Tree : 7
# Avg : 92.4500
# ====== D O N E ====== : 475 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn024-rwl-noaa.txt
# Min : 110 	---> Tree : 8
# Max : 200 	---> Tree : 15
# Avg : 157.2400
# ====== D O N E ====== : 476 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn009-rwl-noaa.txt
# Min : 201 	---> Tree : 3
# Max : 301 	---> Tree : 8
# Avg : 236.0000
# ====== D O N E ====== : 477 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn019-rwl-noaa.txt
# Min : 118 	---> Tree : 3
# Max : 301 	---> Tree : 43
# Avg : 185.3111
# ====== D O N E ====== : 478 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn008-rwl-noaa.txt
# Min : 135 	---> Tree : 8
# Max : 246 	---> Tree : 5
# Avg : 181.3125
# ====== D O N E ====== : 479 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn021-rwl-noaa.txt
# Min : 174 	---> Tree : 4
# Max : 348 	---> Tree : 16
# Avg : 268.2759
# ====== D O N E ====== : 480 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nh005-rwl-noaa.txt
# Min : 50 	---> Tree : 45
# Max : 320 	---> Tree : 36
# Avg : 156.0377
# ====== D O N E ====== : 481 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn010-rwl-noaa.txt
# Min : 118 	---> Tree : 3
# Max : 242 	---> Tree : 1
# Avg : 162.0000
# ====== D O N E ====== : 482 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn006-rwl-noaa.txt
# Min : 245 	---> Tree : 9
# Max : 277 	---> Tree : 1
# Avg : 263.0000
# ====== D O N E ====== : 483 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me049-rwl-noaa.txt
# Min : 111 	---> Tree : 15
# Max : 219 	---> Tree : 29
# Avg : 203.3333
# ====== D O N E ====== : 484 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi029-rwl-noaa.txt
# Min : 82 	---> Tree : 2
# Max : 180 	---> Tree : 4
# Avg : 134.4167
# ====== D O N E ====== : 485 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn026-rwl-noaa.txt
# Min : 129 	---> Tree : 22
# Max : 271 	---> Tree : 17
# Avg : 189.1860
# ====== D O N E ====== : 486 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi021-rwl-noaa.txt
# Min : 110 	---> Tree : 37
# Max : 331 	---> Tree : 5
# Avg : 212.1163
# ====== D O N E ====== : 487 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wi012-rwl-noaa.txt
# Min : 66 	---> Tree : 1
# Max : 190 	---> Tree : 17
# Avg : 116.0526
# ====== D O N E ====== : 488 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi022-rwl-noaa.txt
# Min : 39 	---> Tree : 27
# Max : 354 	---> Tree : 8
# Avg : 172.1220
# ====== D O N E ====== : 489 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn027-rwl-noaa.txt
# Min : 92 	---> Tree : 33
# Max : 346 	---> Tree : 19
# Avg : 202.2549
# ====== D O N E ====== : 490 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn036-rwl-noaa.txt
# Min : 59 	---> Tree : 19
# Max : 74 	---> Tree : 29
# Avg : 67.3000
# ====== D O N E ====== : 491 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn033-rwl-noaa.txt
# Min : 88 	---> Tree : 0
# Max : 256 	---> Tree : 3
# Avg : 173.7931
# ====== D O N E ====== : 492 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi020-rwl-noaa.txt
# Min : 79 	---> Tree : 26
# Max : 286 	---> Tree : 21
# Avg : 192.8333
# ====== D O N E ====== : 493 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wi011-rwl-noaa.txt
# Min : 75 	---> Tree : 12
# Max : 194 	---> Tree : 10
# Avg : 134.9062
# ====== D O N E ====== : 494 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi001-rwl-noaa.txt
# Min : 175 	---> Tree : 29
# Max : 219 	---> Tree : 6
# Avg : 203.3654
# ====== D O N E ====== : 495 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi019-rwl-noaa.txt
# Min : 40 	---> Tree : 28
# Max : 342 	---> Tree : 38
# Avg : 174.5227
# ====== D O N E ====== : 496 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn005-rwl-noaa.txt
# Min : 164 	---> Tree : 20
# Max : 354 	---> Tree : 24
# Avg : 263.1556
# ====== D O N E ====== : 497 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me1-rwl-noaa.txt
# Min : 163 	---> Tree : 6
# Max : 180 	---> Tree : 11
# Avg : 174.0000
# ====== D O N E ====== : 498 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi017-rwl-noaa.txt
# Min : 73 	---> Tree : 7
# Max : 142 	---> Tree : 14
# Avg : 88.7895
# ====== D O N E ====== : 499 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn017-rwl-noaa.txt
# Min : 100 	---> Tree : 34
# Max : 318 	---> Tree : 15
# Avg : 236.2927
# ====== D O N E ====== : 500 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wi002-rwl-noaa.txt
# Min : 132 	---> Tree : 13
# Max : 224 	---> Tree : 21
# Avg : 170.1667
# ====== D O N E ====== : 501 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn014-rwl-noaa.txt
# Min : 91 	---> Tree : 3
# Max : 207 	---> Tree : 9
# Avg : 181.1429
# ====== D O N E ====== : 502 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn013-rwl-noaa.txt
# Min : 244 	---> Tree : 6
# Max : 297 	---> Tree : 2
# Avg : 269.6875
# ====== D O N E ====== : 503 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn002-rwl-noaa.txt
# Min : 202 	---> Tree : 0
# Max : 302 	---> Tree : 9
# Avg : 268.3529
# ====== D O N E ====== : 504 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn015-rwl-noaa.txt
# Min : 120 	---> Tree : 20
# Max : 269 	---> Tree : 1
# Avg : 163.1053
# ====== D O N E ====== : 505 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wv009-rwl-noaa.txt
# Min : 68 	---> Tree : 16
# Max : 188 	---> Tree : 53
# Avg : 130.4000
# ====== D O N E ====== : 506 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me037e-rwl-noaa.txt
# Min : 60 	---> Tree : 33
# Max : 212 	---> Tree : 7
# Avg : 104.6000
# ====== D O N E ====== : 507 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ny005-rwl-noaa.txt
# Min : 125 	---> Tree : 3
# Max : 352 	---> Tree : 27
# Avg : 215.4062
# ====== D O N E ====== : 508 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ny025-rwl-noaa.txt
# Min : 78 	---> Tree : 6
# Max : 380 	---> Tree : 1
# Avg : 205.6923
# ====== D O N E ====== : 509 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  va018-rwl-noaa.txt
# Min : 65 	---> Tree : 6
# Max : 112 	---> Tree : 4
# Avg : 89.0345
# ====== D O N E ====== : 510 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me037l-rwl-noaa.txt
# Min : 60 	---> Tree : 33
# Max : 212 	---> Tree : 7
# Avg : 104.7000
# ====== D O N E ====== : 511 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ny049-rwl-noaa.txt
# Min : 59 	---> Tree : 2
# Max : 398 	---> Tree : 14
# Avg : 134.4565
# ====== D O N E ====== : 512 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ma015-rwl-noaa.txt
# Min : 37 	---> Tree : 51
# Max : 155 	---> Tree : 15
# Avg : 75.0671
# ====== D O N E ====== : 513 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me037-rwl-noaa.txt
# Min : 60 	---> Tree : 33
# Max : 212 	---> Tree : 7
# Avg : 104.7200
# ====== D O N E ====== : 514 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wv004-rwl-noaa.txt
# Min : 44 	---> Tree : 0
# Max : 177 	---> Tree : 15
# Avg : 85.5806
# ====== D O N E ====== : 515 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ca599-rwl-noaa.txt
# Min : 40 	---> Tree : 13
# Max : 169 	---> Tree : 6
# Avg : 95.9565
# ====== D O N E ====== : 516 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  va20-rwl-noaa.txt
# Min : 62 	---> Tree : 5
# Max : 141 	---> Tree : 17
# Avg : 105.0435
# ====== D O N E ====== : 517 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  va20e-rwl-noaa.txt
# Min : 62 	---> Tree : 5
# Max : 147 	---> Tree : 15
# Avg : 105.5909
# ====== D O N E ====== : 518 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ok039-rwl-noaa.txt
# Min : 11 	---> Tree : 25
# Max : 29 	---> Tree : 49
# Avg : 21.5000
# ====== D O N E ====== : 519 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nc6-rwl-noaa.txt
# Min : 53 	---> Tree : 22
# Max : 105 	---> Tree : 24
# Avg : 75.8857
# ====== D O N E ====== : 520 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nc11-rwl-noaa.txt
# Min : 41 	---> Tree : 14
# Max : 141 	---> Tree : 0
# Avg : 72.2500
# ====== D O N E ====== : 521 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  va20l-rwl-noaa.txt
# Min : 62 	---> Tree : 5
# Max : 147 	---> Tree : 15
# Avg : 105.5909
# ====== D O N E ====== : 522 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nc10-rwl-noaa.txt
# Min : 88 	---> Tree : 4
# Max : 192 	---> Tree : 7
# Avg : 158.9583
# ====== D O N E ====== : 523 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi008-rwl-noaa.txt
# Min : 160 	---> Tree : 12
# Max : 333 	---> Tree : 14
# Avg : 232.5714
# ====== D O N E ====== : 524 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me035-rwl-noaa.txt
# Min : 27 	---> Tree : 14
# Max : 108 	---> Tree : 2
# Avg : 72.0000
# ====== D O N E ====== : 525 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me034-rwl-noaa.txt
# Min : 47 	---> Tree : 2
# Max : 154 	---> Tree : 6
# Avg : 100.1000
# ====== D O N E ====== : 526 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  va047-rwl-noaa.txt
# Min : 18 	---> Tree : 17
# Max : 114 	---> Tree : 3
# Avg : 73.0500
# ====== D O N E ====== : 527 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me023-rwl-noaa.txt
# Min : 185 	---> Tree : 20
# Max : 292 	---> Tree : 11
# Avg : 236.9062
# ====== D O N E ====== : 528 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me033-rwl-noaa.txt
# Min : 34 	---> Tree : 5
# Max : 154 	---> Tree : 52
# Avg : 62.0253
# ====== D O N E ====== : 529 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ny014-rwl-noaa.txt
# Min : 183 	---> Tree : 14
# Max : 282 	---> Tree : 1
# Avg : 231.5769
# ====== D O N E ====== : 530 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ny013-rwl-noaa.txt
# Min : 189 	---> Tree : 16
# Max : 351 	---> Tree : 4
# Avg : 248.0000
# ====== D O N E ====== : 531 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wi005-rwl-noaa.txt
# Min : 59 	---> Tree : 11
# Max : 341 	---> Tree : 4
# Avg : 244.6087
# ====== D O N E ====== : 532 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  pa008-rwl-noaa.txt
# Min : 212 	---> Tree : 21
# Max : 304 	---> Tree : 0
# Avg : 269.1250
# ====== D O N E ====== : 533 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  wi014-rwl-noaa.txt
# Min : 43 	---> Tree : 17
# Max : 210 	---> Tree : 13
# Avg : 134.1818
# ====== D O N E ====== : 534 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ia012-rwl-noaa.txt
# Min : 63 	---> Tree : 32
# Max : 146 	---> Tree : 35
# Avg : 86.1020
# ====== D O N E ====== : 535 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ma022-rwl-noaa.txt
# Min : 52 	---> Tree : 6
# Max : 113 	---> Tree : 29
# Avg : 78.3871
# ====== D O N E ====== : 536 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ia014-rwl-noaa.txt
# Min : 65 	---> Tree : 11
# Max : 205 	---> Tree : 31
# Avg : 124.7442
# ====== D O N E ====== : 537 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ny-rwl-noaa.txt
# Min : 98 	---> Tree : 22
# Max : 197 	---> Tree : 3
# Avg : 134.1250
# ====== D O N E ====== : 538 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me-rwl-noaa.txt
# Min : 49 	---> Tree : 14
# Max : 133 	---> Tree : 4
# Avg : 82.2632
# ====== D O N E ====== : 539 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi031-rwl-noaa.txt
# Min : 52 	---> Tree : 0
# Max : 194 	---> Tree : 4
# Avg : 142.5385
# ====== D O N E ====== : 540 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  oh008-rwl-noaa.txt
# Min : 85 	---> Tree : 4
# Max : 164 	---> Tree : 10
# Avg : 129.5294
# ====== D O N E ====== : 541 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ny043-rwl-noaa.txt
# Min : 28 	---> Tree : 41
# Max : 98 	---> Tree : 46
# Avg : 72.6600
# ====== D O N E ====== : 542 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mn031-rwl-noaa.txt
# Min : 79 	---> Tree : 17
# Max : 203 	---> Tree : 0
# Avg : 146.5000
# ====== D O N E ====== : 543 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi015-rwl-noaa.txt
# Min : 17 	---> Tree : 13
# Max : 92 	---> Tree : 1
# Avg : 63.0000
# ====== D O N E ====== : 544 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  me048-rwl-noaa.txt
# Min : 105 	---> Tree : 14
# Max : 187 	---> Tree : 3
# Avg : 148.3158
# ====== D O N E ====== : 545 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ia013-rwl-noaa.txt
# Min : 58 	---> Tree : 20
# Max : 97 	---> Tree : 17
# Avg : 78.0357
# ====== D O N E ====== : 546 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az546-rwl-noaa.txt
# Min : 116 	---> Tree : 3
# Max : 325 	---> Tree : 0
# Avg : 205.1875
# ====== D O N E ====== : 547 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az532-rwl-noaa.txt
# Min : 102 	---> Tree : 1
# Max : 296 	---> Tree : 17
# Avg : 194.8000
# ====== D O N E ====== : 548 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az594-rwl-noaa.txt
# Min : 64 	---> Tree : 59
# Max : 559 	---> Tree : 1
# Avg : 260.9732
# ====== D O N E ====== : 549 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az525-rwl-noaa.txt
# Min : 106 	---> Tree : 5
# Max : 262 	---> Tree : 0
# Avg : 181.7778
# ====== D O N E ====== : 550 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  az550-rwl-noaa.txt
# Min : 55 	---> Tree : 40
# Max : 559 	---> Tree : 69
# Avg : 194.1287
# ====== D O N E ====== : 551 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm585-rwl-noaa.txt
# Min : 112 	---> Tree : 29
# Max : 398 	---> Tree : 20
# Avg : 228.7333
# ====== D O N E ====== : 552 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm604-rwl-noaa.txt
# Min : 69 	---> Tree : 40
# Max : 505 	---> Tree : 52
# Avg : 176.4194
# ====== D O N E ====== : 553 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm614-rwl-noaa.txt
# Min : 47 	---> Tree : 0
# Max : 721 	---> Tree : 66
# Avg : 192.8447
# ====== D O N E ====== : 554 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  nm607-rwl-noaa.txt
# Min : 41 	---> Tree : 80
# Max : 418 	---> Tree : 125
# Avg : 171.5714
# ====== D O N E ====== : 555 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  va039-rwl-noaa.txt
# Min : 22 	---> Tree : 1
# Max : 61 	---> Tree : 0
# Avg : 49.7333
# ====== D O N E ====== : 556 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  ky006-rwl-noaa.txt
# Min : 52 	---> Tree : 3
# Max : 162 	---> Tree : 20
# Avg : 100.4524
# ====== D O N E ====== : 557 of 558 Files
#
#
#  ====== S T A R T I N G ====== :  mi035-rwl-noaa.txt
# Min : 37 	---> Tree : 1
# Max : 113 	---> Tree : 20
# Avg : 88.9259
# ====== D O N E ====== : 558 of 558 Files

# %%
min_val = min(min_info)
max_val = max(min_info)
avg_val = sum(min_info) / len(min_info)
print(f"Min information : {min_val}")
print(f"Max information : {max_val}")
print(f"Avg information : {avg_val:.0f}")
# Out:
# Min information : 1
# Max information : 530
# Avg information : 103

# %%
min_early = min(early)
max_late = max(late)

# %%
print("Earliest First Date : ", min_early)
print("Latest Last Date    : ", max_late)
# Out:
# Earliest First Date :  -6000
# Latest Last Date    :  2023

# %%
print(f"Total Trees : {sum(len_info)}")
# Out:
# Total Trees : 23483
