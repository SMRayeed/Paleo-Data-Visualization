# %% [markdown]
# <a href="https://colab.research.google.com/github/SMRayeed/Paleo-Data-Classification/blob/main/01_Data_Collection_PIPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
from io import StringIO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path = '/content/drive/MyDrive/PIPO/raw/'
files = os.listdir(folder_path)

# %%
drive_path_txt = '/content/drive/MyDrive/PIPO/processed/Files(.txt)/'
drive_path_csv = '/content/drive/MyDrive/PIPO/processed/Files(.csv)/'
os.makedirs(drive_path_txt) if not os.path.exists(drive_path_txt) else None
os.makedirs(drive_path_csv) if not os.path.exists(drive_path_csv) else None

# %%
min_info, avg_info, max_info, len_info, early, late = [], [], [], [], [], []

# %%
ix = 1

for file in files :

  print(" ====== S T A R T I N G ====== : ", file)

  file_path = folder_path + file

  with open(file_path, 'r') as file : text_data = file.read()

  site_name = text_data.split('Site_Name: ')[1].split('\n')[0].strip()
  location = text_data.split('Location: ')[1].split('\n')[0].strip()
  northernmost_latitude = float(text_data.split('Northernmost_Latitude: ')[1].split('\n')[0].strip())
  southernmost_latitude = float(text_data.split('Southernmost_Latitude: ')[1].split('\n')[0].strip())
  easternmost_longitude = float(text_data.split('Easternmost_Longitude: ')[1].split('\n')[0].strip())
  westernmost_longitude = float(text_data.split('Westernmost_Longitude: ')[1].split('\n')[0].strip())

  collection_name = text_data.split('Collection_Name: ')[1].split('\n')[0].strip()
  first_year = int((text_data.split('First_Year: ')[1].split('\n')[0].strip()) or (text_data.split('Earliest_Year: ')[1].split('\n')[0].strip()))
  last_year = int((text_data.split('Last_Year: ')[1].split('\n')[0].strip()) or (text_data.split('Most_Recent_Year: ')[1].split('\n')[0].strip()))

  early.append(first_year)
  late.append(last_year)
  species_name = text_data.split('Species_Name: ')[1].split('\n')[0].strip()
  common_name = text_data.split('Common_Name: ')[1].split('\n')[0].strip()
  tree_species_code = text_data.split('Tree_Species_Code: ')[1].split('\n')[0].strip()

  output_txt_file_name = f"{collection_name}.txt"
  output_txt_file_path = drive_path_txt + output_txt_file_name

  with open(output_txt_file_path, 'w') as output_file:
    output_file.write("Site Information\n")
    output_file.write("================\n")
    output_file.write(f"Site Name: {site_name}\n")
    output_file.write(f"Location: {location}\n")
    output_file.write(f"Northernmost Latitude: {northernmost_latitude}\n")
    output_file.write(f"Southernmost Latitude: {southernmost_latitude}\n")
    output_file.write(f"Easternmost Longitude: {easternmost_longitude}\n")
    output_file.write(f"Westernmost Longitude: {westernmost_longitude}\n")

    output_file.write("Data Collection\n")
    output_file.write("===============\n")
    output_file.write(f"Collection Name: {collection_name}\n")
    output_file.write(f"First Year: {first_year}\n")
    output_file.write(f"Last Year: {last_year}\n\n")

    output_file.write("Species Information\n")
    output_file.write("===================\n")
    output_file.write(f"Species Name: {species_name}\n")
    output_file.write(f"Common Name: {common_name}\n")
    output_file.write(f"Tree Species Code: {tree_species_code}\n")

  data_start_line = next(i for i, line in enumerate(text_data.strip().split('\n')) if line.startswith('age_CE') and not line.startswith('##'))
  df = pd.read_csv(StringIO(text_data), delim_whitespace=True, skiprows=data_start_line, index_col='age_CE')
  df.index.name = 'trees'
  df = df.transpose()
  df['site'] = site_name
  df['loc'] = location
  df['N'] = northernmost_latitude
  df['S'] = southernmost_latitude
  df['E'] = easternmost_longitude
  df['W'] = easternmost_longitude
  df['species'] = tree_species_code
  df = df.reset_index()

  output_csv_file_name = f"{collection_name}.csv"
  output_csv_file_path = drive_path_csv + output_csv_file_name
  df.to_csv(output_csv_file_path, index=False)

  non_nan_counts = df.iloc[:, :-7].notna().sum(axis=1)
  df_min_tree = non_nan_counts.idxmin()
  df_min = non_nan_counts[df_min_tree]
  df_max_tree = non_nan_counts.idxmax()
  df_max = non_nan_counts[df_max_tree]
  df_avg = non_nan_counts.mean()

  print(f"Min : {df_min} \t---> Tree : {df_min_tree}")
  print(f"Max : {df_max} \t---> Tree : {df_max_tree}")
  print(f"Avg : {df_avg:.4f}")

  min_info.append(df_min)
  avg_info.append(df_avg)
  max_info.append(df_max)
  len_info.append(len(df))

  print(f"====== D O N E ====== : {ix} of {len(files)} Files\n\n")

  ix += 1
# Out:
#  ====== S T A R T I N G ====== :  az607-rwl-noaa.txt
# Min : 52 	---> Tree : 19
# Max : 180 	---> Tree : 0
# Avg : 113.5200
# ====== D O N E ====== : 1 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca598-rwl-noaa.txt
# Min : 101 	---> Tree : 18
# Max : 167 	---> Tree : 25
# Avg : 140.7308
# ====== D O N E ====== : 2 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az509-rwl-noaa.txt
# Min : 121 	---> Tree : 14
# Max : 259 	---> Tree : 2
# Avg : 159.3810
# ====== D O N E ====== : 3 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az608-rwl-noaa.txt
# Min : 51 	---> Tree : 3
# Max : 398 	---> Tree : 58
# Avg : 240.1333
# ====== D O N E ====== : 4 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co663-rwl-noaa.txt
# Min : 63 	---> Tree : 20
# Max : 369 	---> Tree : 10
# Avg : 229.3750
# ====== D O N E ====== : 5 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az606-rwl-noaa.txt
# Min : 48 	---> Tree : 16
# Max : 367 	---> Tree : 30
# Avg : 253.1304
# ====== D O N E ====== : 6 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ne004-rwl-noaa.txt
# Min : 91 	---> Tree : 44
# Max : 247 	---> Tree : 40
# Avg : 147.2391
# ====== D O N E ====== : 7 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca729-rwl-noaa.txt
# Min : 11 	---> Tree : 35
# Max : 288 	---> Tree : 0
# Avg : 41.9683
# ====== D O N E ====== : 8 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca685-rwl-noaa.txt
# Min : 111 	---> Tree : 0
# Max : 111 	---> Tree : 0
# Avg : 111.0000
# ====== D O N E ====== : 9 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az069-rwl-noaa.txt
# Min : 315 	---> Tree : 1
# Max : 373 	---> Tree : 3
# Avg : 352.8333
# ====== D O N E ====== : 10 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az072-rwl-noaa.txt
# Min : 316 	---> Tree : 1
# Max : 491 	---> Tree : 2
# Avg : 372.1667
# ====== D O N E ====== : 11 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  id003-rwl-noaa.txt
# Min : 66 	---> Tree : 14
# Max : 305 	---> Tree : 7
# Avg : 122.9423
# ====== D O N E ====== : 12 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or001-rwl-noaa.txt
# Min : 121 	---> Tree : 13
# Max : 480 	---> Tree : 3
# Avg : 269.9000
# ====== D O N E ====== : 13 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  id001-rwl-noaa.txt
# Min : 124 	---> Tree : 1
# Max : 266 	---> Tree : 0
# Avg : 203.9231
# ====== D O N E ====== : 14 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa012-rwl-noaa.txt
# Min : 72 	---> Tree : 4
# Max : 164 	---> Tree : 0
# Avg : 113.4231
# ====== D O N E ====== : 15 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa026-rwl-noaa.txt
# Min : 103 	---> Tree : 5
# Max : 371 	---> Tree : 7
# Avg : 235.3214
# ====== D O N E ====== : 16 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa015-rwl-noaa.txt
# Min : 171 	---> Tree : 6
# Max : 337 	---> Tree : 1
# Avg : 287.1500
# ====== D O N E ====== : 17 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa010-rwl-noaa.txt
# Min : 155 	---> Tree : 9
# Max : 324 	---> Tree : 7
# Avg : 236.1500
# ====== D O N E ====== : 18 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa018-rwl-noaa.txt
# Min : 46 	---> Tree : 0
# Max : 90 	---> Tree : 11
# Avg : 68.8750
# ====== D O N E ====== : 19 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa037-rwl-noaa.txt
# Min : 109 	---> Tree : 0
# Max : 329 	---> Tree : 10
# Avg : 215.2500
# ====== D O N E ====== : 20 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  id002-rwl-noaa.txt
# Min : 163 	---> Tree : 4
# Max : 306 	---> Tree : 13
# Avg : 263.2143
# ====== D O N E ====== : 21 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa038-rwl-noaa.txt
# Min : 109 	---> Tree : 1
# Max : 487 	---> Tree : 13
# Avg : 290.2500
# ====== D O N E ====== : 22 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa013-rwl-noaa.txt
# Min : 81 	---> Tree : 2
# Max : 354 	---> Tree : 15
# Avg : 195.7222
# ====== D O N E ====== : 23 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa009-rwl-noaa.txt
# Min : 154 	---> Tree : 2
# Max : 282 	---> Tree : 14
# Avg : 215.1250
# ====== D O N E ====== : 24 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa011-rwl-noaa.txt
# Min : 150 	---> Tree : 6
# Max : 345 	---> Tree : 0
# Avg : 265.2083
# ====== D O N E ====== : 25 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm512t-rwl-noaa.txt
# Min : 99 	---> Tree : 0
# Max : 319 	---> Tree : 2
# Avg : 195.0000
# ====== D O N E ====== : 26 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm529n-rwl-noaa.txt
# Min : 46 	---> Tree : 1
# Max : 311 	---> Tree : 0
# Avg : 220.3846
# ====== D O N E ====== : 27 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm512d-rwl-noaa.txt
# Min : 99 	---> Tree : 0
# Max : 319 	---> Tree : 2
# Avg : 195.0000
# ====== D O N E ====== : 28 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm529e-rwl-noaa.txt
# Min : 46 	---> Tree : 1
# Max : 311 	---> Tree : 0
# Avg : 220.3846
# ====== D O N E ====== : 29 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm512-rwl-noaa.txt
# Min : 99 	---> Tree : 0
# Max : 319 	---> Tree : 2
# Avg : 195.0000
# ====== D O N E ====== : 30 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm512i-rwl-noaa.txt
# Min : 100 	---> Tree : 0
# Max : 320 	---> Tree : 2
# Avg : 196.0000
# ====== D O N E ====== : 31 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm529-rwl-noaa.txt
# Min : 46 	---> Tree : 1
# Max : 311 	---> Tree : 0
# Avg : 220.3846
# ====== D O N E ====== : 32 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm529d-rwl-noaa.txt
# Min : 46 	---> Tree : 1
# Max : 310 	---> Tree : 0
# Avg : 219.7692
# ====== D O N E ====== : 33 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm529t-rwl-noaa.txt
# Min : 46 	---> Tree : 1
# Max : 310 	---> Tree : 0
# Avg : 219.7692
# ====== D O N E ====== : 34 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm512l-rwl-noaa.txt
# Min : 99 	---> Tree : 0
# Max : 319 	---> Tree : 2
# Avg : 195.0000
# ====== D O N E ====== : 35 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa016-rwl-noaa.txt
# Min : 135 	---> Tree : 3
# Max : 295 	---> Tree : 13
# Avg : 209.5000
# ====== D O N E ====== : 36 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm512x-rwl-noaa.txt
# Min : 99 	---> Tree : 0
# Max : 319 	---> Tree : 2
# Avg : 195.0000
# ====== D O N E ====== : 37 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm529l-rwl-noaa.txt
# Min : 46 	---> Tree : 1
# Max : 311 	---> Tree : 0
# Avg : 220.3846
# ====== D O N E ====== : 38 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm512n-rwl-noaa.txt
# Min : 100 	---> Tree : 0
# Max : 320 	---> Tree : 2
# Avg : 196.0000
# ====== D O N E ====== : 39 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm529x-rwl-noaa.txt
# Min : 46 	---> Tree : 1
# Max : 310 	---> Tree : 0
# Avg : 219.7692
# ====== D O N E ====== : 40 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm512e-rwl-noaa.txt
# Min : 100 	---> Tree : 0
# Max : 320 	---> Tree : 2
# Avg : 196.0000
# ====== D O N E ====== : 41 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm529i-rwl-noaa.txt
# Min : 46 	---> Tree : 1
# Max : 311 	---> Tree : 0
# Avg : 220.3846
# ====== D O N E ====== : 42 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa014-rwl-noaa.txt
# Min : 129 	---> Tree : 15
# Max : 439 	---> Tree : 16
# Avg : 261.3846
# ====== D O N E ====== : 43 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ut021-rwl-noaa.txt
# Min : 191 	---> Tree : 12
# Max : 408 	---> Tree : 27
# Avg : 308.5000
# ====== D O N E ====== : 44 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az077-rwl-noaa.txt
# Min : 75 	---> Tree : 12
# Max : 331 	---> Tree : 31
# Avg : 170.7500
# ====== D O N E ====== : 45 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm052-rwl-noaa.txt
# Min : 178 	---> Tree : 14
# Max : 342 	---> Tree : 10
# Avg : 281.5625
# ====== D O N E ====== : 46 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nv522-rwl-noaa.txt
# Min : 66 	---> Tree : 16
# Max : 606 	---> Tree : 22
# Avg : 392.3243
# ====== D O N E ====== : 47 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm597-rwl-noaa.txt
# Min : 80 	---> Tree : 14
# Max : 425 	---> Tree : 40
# Avg : 223.1647
# ====== D O N E ====== : 48 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az572-rwl-noaa.txt
# Min : 46 	---> Tree : 37
# Max : 575 	---> Tree : 46
# Avg : 237.6769
# ====== D O N E ====== : 49 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nv522l-rwl-noaa.txt
# Min : 66 	---> Tree : 16
# Max : 606 	---> Tree : 22
# Avg : 392.3243
# ====== D O N E ====== : 50 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nv522e-rwl-noaa.txt
# Min : 66 	---> Tree : 16
# Max : 606 	---> Tree : 22
# Avg : 392.3243
# ====== D O N E ====== : 51 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az090-rwl-noaa.txt
# Min : 227 	---> Tree : 5
# Max : 363 	---> Tree : 21
# Avg : 295.0333
# ====== D O N E ====== : 52 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm033-rwl-noaa.txt
# Min : 166 	---> Tree : 18
# Max : 438 	---> Tree : 12
# Avg : 267.6818
# ====== D O N E ====== : 53 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm500-rwl-noaa.txt
# Min : 115 	---> Tree : 30
# Max : 266 	---> Tree : 13
# Avg : 165.1250
# ====== D O N E ====== : 54 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm603-rwl-noaa.txt
# Min : 53 	---> Tree : 138
# Max : 665 	---> Tree : 78
# Avg : 262.7914
# ====== D O N E ====== : 55 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm021-rwl-noaa.txt
# Min : 120 	---> Tree : 0
# Max : 410 	---> Tree : 18
# Avg : 257.4231
# ====== D O N E ====== : 56 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az088-rwl-noaa.txt
# Min : 131 	---> Tree : 12
# Max : 310 	---> Tree : 2
# Avg : 231.5833
# ====== D O N E ====== : 57 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az087-rwl-noaa.txt
# Min : 162 	---> Tree : 10
# Max : 362 	---> Tree : 27
# Avg : 242.4643
# ====== D O N E ====== : 58 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az079-rwl-noaa.txt
# Min : 68 	---> Tree : 15
# Max : 296 	---> Tree : 0
# Avg : 136.6500
# ====== D O N E ====== : 59 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co037-rwl-noaa.txt
# Min : 166 	---> Tree : 14
# Max : 286 	---> Tree : 4
# Avg : 247.5000
# ====== D O N E ====== : 60 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm029-rwl-noaa.txt
# Min : 148 	---> Tree : 29
# Max : 379 	---> Tree : 12
# Avg : 292.9565
# ====== D O N E ====== : 61 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az089-rwl-noaa.txt
# Min : 170 	---> Tree : 18
# Max : 378 	---> Tree : 20
# Avg : 299.2500
# ====== D O N E ====== : 62 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm036-rwl-noaa.txt
# Min : 124 	---> Tree : 14
# Max : 283 	---> Tree : 21
# Avg : 216.2000
# ====== D O N E ====== : 63 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az100-rwl-noaa.txt
# Min : 140 	---> Tree : 21
# Max : 315 	---> Tree : 23
# Avg : 232.7308
# ====== D O N E ====== : 64 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa043-rwl-noaa.txt
# Min : 117 	---> Tree : 8
# Max : 499 	---> Tree : 26
# Avg : 221.7273
# ====== D O N E ====== : 65 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co040-rwl-noaa.txt
# Min : 136 	---> Tree : 17
# Max : 316 	---> Tree : 13
# Avg : 224.5000
# ====== D O N E ====== : 66 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az617-rwl-noaa.txt
# Min : 20 	---> Tree : 325
# Max : 251 	---> Tree : 558
# Avg : 78.3931
# ====== D O N E ====== : 67 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co030-rwl-noaa.txt
# Min : 116 	---> Tree : 18
# Max : 276 	---> Tree : 0
# Avg : 174.1818
# ====== D O N E ====== : 68 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az098-rwl-noaa.txt
# Min : 174 	---> Tree : 10
# Max : 326 	---> Tree : 7
# Avg : 267.7083
# ====== D O N E ====== : 69 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  sd001-rwl-noaa.txt
# Min : 156 	---> Tree : 17
# Max : 406 	---> Tree : 14
# Avg : 249.9474
# ====== D O N E ====== : 70 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm501-rwl-noaa.txt
# Min : 116 	---> Tree : 3
# Max : 257 	---> Tree : 27
# Avg : 198.8333
# ====== D O N E ====== : 71 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca525-rwl-noaa.txt
# Min : 189 	---> Tree : 19
# Max : 356 	---> Tree : 7
# Avg : 280.3846
# ====== D O N E ====== : 72 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa059-rwl-noaa.txt
# Min : 169 	---> Tree : 21
# Max : 549 	---> Tree : 5
# Avg : 329.5897
# ====== D O N E ====== : 73 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca526-rwl-noaa.txt
# Min : 190 	---> Tree : 17
# Max : 457 	---> Tree : 14
# Avg : 290.2778
# ====== D O N E ====== : 74 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az521-rwl-noaa.txt
# Min : 59 	---> Tree : 2
# Max : 449 	---> Tree : 12
# Avg : 206.0746
# ====== D O N E ====== : 75 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az524-rwl-noaa.txt
# Min : 164 	---> Tree : 13
# Max : 299 	---> Tree : 0
# Avg : 221.8125
# ====== D O N E ====== : 76 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co538-rwl-noaa.txt
# Min : 189 	---> Tree : 2
# Max : 329 	---> Tree : 13
# Avg : 259.3333
# ====== D O N E ====== : 77 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co532-rwl-noaa.txt
# Min : 83 	---> Tree : 18
# Max : 364 	---> Tree : 10
# Avg : 248.0769
# ====== D O N E ====== : 78 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az513-rwl-noaa.txt
# Min : 242 	---> Tree : 28
# Max : 428 	---> Tree : 18
# Avg : 321.2812
# ====== D O N E ====== : 79 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co534-rwl-noaa.txt
# Min : 160 	---> Tree : 5
# Max : 311 	---> Tree : 11
# Avg : 233.6250
# ====== D O N E ====== : 80 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or027-rwl-noaa.txt
# Min : 182 	---> Tree : 9
# Max : 487 	---> Tree : 19
# Avg : 320.3750
# ====== D O N E ====== : 81 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az520-rwl-noaa.txt
# Min : 201 	---> Tree : 9
# Max : 534 	---> Tree : 13
# Avg : 302.0000
# ====== D O N E ====== : 82 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca527-rwl-noaa.txt
# Min : 28 	---> Tree : 4
# Max : 582 	---> Tree : 29
# Avg : 325.5278
# ====== D O N E ====== : 83 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca524-rwl-noaa.txt
# Min : 143 	---> Tree : 11
# Max : 321 	---> Tree : 33
# Avg : 247.7895
# ====== D O N E ====== : 84 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm566-rwl-noaa.txt
# Min : 108 	---> Tree : 26
# Max : 430 	---> Tree : 11
# Avg : 330.4194
# ====== D O N E ====== : 85 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az522-rwl-noaa.txt
# Min : 227 	---> Tree : 1
# Max : 333 	---> Tree : 22
# Avg : 293.6071
# ====== D O N E ====== : 86 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az523-rwl-noaa.txt
# Min : 192 	---> Tree : 7
# Max : 297 	---> Tree : 24
# Avg : 232.5000
# ====== D O N E ====== : 87 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa060-rwl-noaa.txt
# Min : 132 	---> Tree : 28
# Max : 336 	---> Tree : 15
# Avg : 223.3000
# ====== D O N E ====== : 88 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm567-rwl-noaa.txt
# Min : 117 	---> Tree : 13
# Max : 460 	---> Tree : 4
# Avg : 235.7778
# ====== D O N E ====== : 89 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co551-rwl-noaa.txt
# Min : 166 	---> Tree : 3
# Max : 308 	---> Tree : 15
# Avg : 204.7083
# ====== D O N E ====== : 90 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az530-rwl-noaa.txt
# Min : 105 	---> Tree : 8
# Max : 278 	---> Tree : 10
# Avg : 202.2857
# ====== D O N E ====== : 91 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az540-rwl-noaa.txt
# Min : 151 	---> Tree : 13
# Max : 355 	---> Tree : 7
# Avg : 277.3125
# ====== D O N E ====== : 92 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az533-rwl-noaa.txt
# Min : 176 	---> Tree : 16
# Max : 422 	---> Tree : 11
# Avg : 347.5789
# ====== D O N E ====== : 93 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az541-rwl-noaa.txt
# Min : 205 	---> Tree : 4
# Max : 347 	---> Tree : 5
# Avg : 271.1818
# ====== D O N E ====== : 94 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az542-rwl-noaa.txt
# Min : 218 	---> Tree : 5
# Max : 366 	---> Tree : 22
# Avg : 307.4167
# ====== D O N E ====== : 95 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az526-rwl-noaa.txt
# Min : 100 	---> Tree : 7
# Max : 275 	---> Tree : 19
# Avg : 176.4000
# ====== D O N E ====== : 96 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az527-rwl-noaa.txt
# Min : 126 	---> Tree : 14
# Max : 334 	---> Tree : 2
# Avg : 218.0556
# ====== D O N E ====== : 97 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co541-rwl-noaa.txt
# Min : 168 	---> Tree : 7
# Max : 289 	---> Tree : 2
# Avg : 210.1000
# ====== D O N E ====== : 98 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az545-rwl-noaa.txt
# Min : 98 	---> Tree : 8
# Max : 334 	---> Tree : 19
# Avg : 229.0000
# ====== D O N E ====== : 99 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az538-rwl-noaa.txt
# Min : 216 	---> Tree : 17
# Max : 290 	---> Tree : 1
# Avg : 264.3600
# ====== D O N E ====== : 100 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co539-rwl-noaa.txt
# Min : 99 	---> Tree : 6
# Max : 441 	---> Tree : 15
# Avg : 301.4800
# ====== D O N E ====== : 101 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co544-rwl-noaa.txt
# Min : 102 	---> Tree : 2
# Max : 560 	---> Tree : 9
# Avg : 249.3182
# ====== D O N E ====== : 102 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az543-rwl-noaa.txt
# Min : 159 	---> Tree : 12
# Max : 398 	---> Tree : 35
# Avg : 276.8649
# ====== D O N E ====== : 103 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az539-rwl-noaa.txt
# Min : 256 	---> Tree : 11
# Max : 367 	---> Tree : 10
# Avg : 304.3077
# ====== D O N E ====== : 104 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co542-rwl-noaa.txt
# Min : 167 	---> Tree : 10
# Max : 331 	---> Tree : 0
# Avg : 203.8182
# ====== D O N E ====== : 105 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az528-rwl-noaa.txt
# Min : 165 	---> Tree : 17
# Max : 223 	---> Tree : 5
# Avg : 187.5000
# ====== D O N E ====== : 106 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co550-rwl-noaa.txt
# Min : 195 	---> Tree : 10
# Max : 307 	---> Tree : 14
# Avg : 221.0000
# ====== D O N E ====== : 107 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm618-rwl-noaa.txt
# Min : 53 	---> Tree : 11
# Max : 331 	---> Tree : 8
# Avg : 116.0000
# ====== D O N E ====== : 108 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm617-rwl-noaa.txt
# Min : 92 	---> Tree : 25
# Max : 325 	---> Tree : 33
# Avg : 198.6613
# ====== D O N E ====== : 109 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az135-rwl-noaa.txt
# Min : 262 	---> Tree : 14
# Max : 404 	---> Tree : 2
# Avg : 357.7778
# ====== D O N E ====== : 110 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az547-rwl-noaa.txt
# Min : 269 	---> Tree : 5
# Max : 575 	---> Tree : 2
# Avg : 379.4762
# ====== D O N E ====== : 111 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co548-rwl-noaa.txt
# Min : 99 	---> Tree : 4
# Max : 349 	---> Tree : 23
# Avg : 219.6071
# ====== D O N E ====== : 112 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co555-rwl-noaa.txt
# Min : 101 	---> Tree : 23
# Max : 690 	---> Tree : 43
# Avg : 270.7952
# ====== D O N E ====== : 113 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az569-rwl-noaa.txt
# Min : 93 	---> Tree : 10
# Max : 354 	---> Tree : 5
# Avg : 210.8800
# ====== D O N E ====== : 114 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm589-rwl-noaa.txt
# Min : 59 	---> Tree : 2
# Max : 436 	---> Tree : 10
# Avg : 184.6607
# ====== D O N E ====== : 115 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm588-rwl-noaa.txt
# Min : 61 	---> Tree : 61
# Max : 410 	---> Tree : 33
# Avg : 211.6000
# ====== D O N E ====== : 116 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca568-rwl-noaa.txt
# Min : 96 	---> Tree : 27
# Max : 112 	---> Tree : 0
# Avg : 111.4737
# ====== D O N E ====== : 117 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca079-rwl-noaa.txt
# Min : 135 	---> Tree : 15
# Max : 425 	---> Tree : 0
# Avg : 259.9231
# ====== D O N E ====== : 118 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa5-rwl-noaa.txt
# Min : 57 	---> Tree : 1
# Max : 67 	---> Tree : 4
# Avg : 59.8000
# ====== D O N E ====== : 119 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az043-rwl-noaa.txt
# Min : 119 	---> Tree : 2
# Max : 307 	---> Tree : 4
# Avg : 229.6429
# ====== D O N E ====== : 120 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca082-rwl-noaa.txt
# Min : 141 	---> Tree : 12
# Max : 482 	---> Tree : 36
# Avg : 291.2000
# ====== D O N E ====== : 121 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca067-rwl-noaa.txt
# Min : 93 	---> Tree : 7
# Max : 489 	---> Tree : 13
# Avg : 309.8919
# ====== D O N E ====== : 122 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca065-rwl-noaa.txt
# Min : 104 	---> Tree : 21
# Max : 594 	---> Tree : 24
# Avg : 315.8605
# ====== D O N E ====== : 123 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm047-rwl-noaa.txt
# Min : 59 	---> Tree : 19
# Max : 336 	---> Tree : 15
# Avg : 195.0500
# ====== D O N E ====== : 124 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca583-rwl-noaa.txt
# Min : 85 	---> Tree : 21
# Max : 112 	---> Tree : 0
# Avg : 108.8000
# ====== D O N E ====== : 125 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca578-rwl-noaa.txt
# Min : 89 	---> Tree : 2
# Max : 112 	---> Tree : 0
# Avg : 110.7222
# ====== D O N E ====== : 126 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca679-rwl-noaa.txt
# Min : 73 	---> Tree : 37
# Max : 545 	---> Tree : 2
# Avg : 243.0500
# ====== D O N E ====== : 127 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  id016-rwl-noaa.txt
# Min : 101 	---> Tree : 32
# Max : 353 	---> Tree : 23
# Avg : 237.4524
# ====== D O N E ====== : 128 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or085-rwl-noaa.txt
# Min : 162 	---> Tree : 0
# Max : 399 	---> Tree : 43
# Avg : 291.3636
# ====== D O N E ====== : 129 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca674-rwl-noaa.txt
# Min : 84 	---> Tree : 67
# Max : 550 	---> Tree : 1
# Avg : 310.0429
# ====== D O N E ====== : 130 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az596-rwl-noaa.txt
# Min : 30 	---> Tree : 36
# Max : 149 	---> Tree : 8
# Avg : 74.2000
# ====== D O N E ====== : 131 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ut539-rwl-noaa.txt
# Min : 77 	---> Tree : 39
# Max : 407 	---> Tree : 4
# Avg : 226.2927
# ====== D O N E ====== : 132 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca588-rwl-noaa.txt
# Min : 90 	---> Tree : 31
# Max : 112 	---> Tree : 0
# Avg : 110.1795
# ====== D O N E ====== : 133 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca676-rwl-noaa.txt
# Min : 66 	---> Tree : 41
# Max : 594 	---> Tree : 5
# Avg : 252.0702
# ====== D O N E ====== : 134 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca585-rwl-noaa.txt
# Min : 81 	---> Tree : 19
# Max : 112 	---> Tree : 0
# Avg : 97.0357
# ====== D O N E ====== : 135 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  mt128-rwl-noaa.txt
# Min : 106 	---> Tree : 30
# Max : 406 	---> Tree : 46
# Avg : 215.5745
# ====== D O N E ====== : 136 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca628-rwl-noaa.txt
# Min : 212 	---> Tree : 44
# Max : 550 	---> Tree : 48
# Avg : 369.4717
# ====== D O N E ====== : 137 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nd001-rwl-noaa.txt
# Min : 20 	---> Tree : 28
# Max : 400 	---> Tree : 32
# Avg : 230.5882
# ====== D O N E ====== : 138 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az565-rwl-noaa.txt
# Min : 62 	---> Tree : 30
# Max : 398 	---> Tree : 24
# Avg : 198.3710
# ====== D O N E ====== : 139 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az601-rwl-noaa.txt
# Min : 57 	---> Tree : 8
# Max : 126 	---> Tree : 3
# Avg : 96.5000
# ====== D O N E ====== : 140 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az602-rwl-noaa.txt
# Min : 61 	---> Tree : 5
# Max : 106 	---> Tree : 21
# Avg : 78.8000
# ====== D O N E ====== : 141 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az604-rwl-noaa.txt
# Min : 51 	---> Tree : 10
# Max : 155 	---> Tree : 11
# Avg : 80.3529
# ====== D O N E ====== : 142 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az567-rwl-noaa.txt
# Min : 77 	---> Tree : 18
# Max : 174 	---> Tree : 2
# Avg : 121.7000
# ====== D O N E ====== : 143 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  sd004-rwl-noaa.txt
# Min : 111 	---> Tree : 9
# Max : 342 	---> Tree : 15
# Avg : 222.5000
# ====== D O N E ====== : 144 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  sd008-rwl-noaa.txt
# Min : 84 	---> Tree : 3
# Max : 340 	---> Tree : 47
# Avg : 222.4706
# ====== D O N E ====== : 145 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az599-rwl-noaa.txt
# Min : 49 	---> Tree : 3
# Max : 149 	---> Tree : 4
# Avg : 102.1429
# ====== D O N E ====== : 146 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  sd002-rwl-noaa.txt
# Min : 168 	---> Tree : 15
# Max : 393 	---> Tree : 19
# Avg : 277.2424
# ====== D O N E ====== : 147 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az598-rwl-noaa.txt
# Min : 33 	---> Tree : 40
# Max : 155 	---> Tree : 29
# Avg : 74.0606
# ====== D O N E ====== : 148 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  sd016-rwl-noaa.txt
# Min : 164 	---> Tree : 10
# Max : 377 	---> Tree : 5
# Avg : 266.0000
# ====== D O N E ====== : 149 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm044-rwl-noaa.txt
# Min : 81 	---> Tree : 2
# Max : 458 	---> Tree : 7
# Avg : 266.2222
# ====== D O N E ====== : 150 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az620-rwl-noaa.txt
# Min : 150 	---> Tree : 2
# Max : 352 	---> Tree : 3
# Avg : 227.3125
# ====== D O N E ====== : 151 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az618-rwl-noaa.txt
# Min : 120 	---> Tree : 5
# Max : 356 	---> Tree : 2
# Avg : 255.2941
# ====== D O N E ====== : 152 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az619-rwl-noaa.txt
# Min : 157 	---> Tree : 14
# Max : 357 	---> Tree : 10
# Avg : 267.2353
# ====== D O N E ====== : 153 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  sd017-rwl-noaa.txt
# Min : 58 	---> Tree : 16
# Max : 705 	---> Tree : 0
# Avg : 283.3750
# ====== D O N E ====== : 154 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az592-rwl-noaa.txt
# Min : 91 	---> Tree : 2
# Max : 389 	---> Tree : 76
# Avg : 264.4737
# ====== D O N E ====== : 155 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az575-rwl-noaa.txt
# Min : 49 	---> Tree : 11
# Max : 195 	---> Tree : 2
# Avg : 115.1875
# ====== D O N E ====== : 156 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  sd012-rwl-noaa.txt
# Min : 69 	---> Tree : 18
# Max : 247 	---> Tree : 23
# Avg : 151.0000
# ====== D O N E ====== : 157 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az623-rwl-noaa.txt
# Min : 133 	---> Tree : 6
# Max : 325 	---> Tree : 15
# Avg : 215.5625
# ====== D O N E ====== : 158 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az622-rwl-noaa.txt
# Min : 181 	---> Tree : 14
# Max : 369 	---> Tree : 10
# Avg : 282.7368
# ====== D O N E ====== : 159 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az621-rwl-noaa.txt
# Min : 173 	---> Tree : 11
# Max : 419 	---> Tree : 0
# Avg : 273.1579
# ====== D O N E ====== : 160 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or005-rwl-noaa.txt
# Min : 187 	---> Tree : 8
# Max : 375 	---> Tree : 0
# Avg : 264.1000
# ====== D O N E ====== : 161 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az042-rwl-noaa.txt
# Min : 113 	---> Tree : 15
# Max : 307 	---> Tree : 6
# Avg : 189.4000
# ====== D O N E ====== : 162 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or002-rwl-noaa.txt
# Min : 116 	---> Tree : 13
# Max : 545 	---> Tree : 3
# Avg : 315.4500
# ====== D O N E ====== : 163 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co577w-rwl-noaa.txt
# Min : 91 	---> Tree : 18
# Max : 268 	---> Tree : 3
# Avg : 171.5714
# ====== D O N E ====== : 164 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  mt137-rwl-noaa.txt
# Min : 154 	---> Tree : 7
# Max : 432 	---> Tree : 3
# Avg : 252.4444
# ====== D O N E ====== : 165 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co557-rwl-noaa.txt
# Min : 88 	---> Tree : 19
# Max : 345 	---> Tree : 18
# Avg : 275.0000
# ====== D O N E ====== : 166 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  mt167-rwl-noaa.txt
# Min : 115 	---> Tree : 21
# Max : 354 	---> Tree : 29
# Avg : 255.2581
# ====== D O N E ====== : 167 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  id019-rwl-noaa.txt
# Min : 103 	---> Tree : 9
# Max : 399 	---> Tree : 21
# Avg : 183.7105
# ====== D O N E ====== : 168 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co577p-rwl-noaa.txt
# Min : 91 	---> Tree : 18
# Max : 268 	---> Tree : 3
# Avg : 171.5714
# ====== D O N E ====== : 169 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co558-rwl-noaa.txt
# Min : 107 	---> Tree : 26
# Max : 393 	---> Tree : 18
# Avg : 291.3793
# ====== D O N E ====== : 170 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  mt144-rwl-noaa.txt
# Min : 51 	---> Tree : 24
# Max : 446 	---> Tree : 52
# Avg : 181.8000
# ====== D O N E ====== : 171 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  id018-rwl-noaa.txt
# Min : 144 	---> Tree : 22
# Max : 426 	---> Tree : 19
# Avg : 271.1818
# ====== D O N E ====== : 172 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  mt138-rwl-noaa.txt
# Min : 154 	---> Tree : 3
# Max : 336 	---> Tree : 10
# Avg : 250.3333
# ====== D O N E ====== : 173 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca702-rwl-noaa.txt
# Min : 33 	---> Tree : 37
# Max : 216 	---> Tree : 32
# Avg : 89.4096
# ====== D O N E ====== : 174 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or090-rwl-noaa.txt
# Min : 71 	---> Tree : 28
# Max : 496 	---> Tree : 41
# Avg : 287.6000
# ====== D O N E ====== : 175 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co560-rwl-noaa.txt
# Min : 119 	---> Tree : 1
# Max : 324 	---> Tree : 20
# Avg : 222.0870
# ====== D O N E ====== : 176 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co559-rwl-noaa.txt
# Min : 152 	---> Tree : 3
# Max : 399 	---> Tree : 15
# Avg : 284.7826
# ====== D O N E ====== : 177 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or004-rwl-noaa.txt
# Min : 116 	---> Tree : 16
# Max : 401 	---> Tree : 0
# Avg : 255.7143
# ====== D O N E ====== : 178 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  mt139-rwl-noaa.txt
# Min : 64 	---> Tree : 7
# Max : 280 	---> Tree : 25
# Avg : 170.0333
# ====== D O N E ====== : 179 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co577x-rwl-noaa.txt
# Min : 91 	---> Tree : 18
# Max : 268 	---> Tree : 3
# Avg : 171.5714
# ====== D O N E ====== : 180 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co573e-rwl-noaa.txt
# Min : 65 	---> Tree : 5
# Max : 171 	---> Tree : 8
# Avg : 112.1053
# ====== D O N E ====== : 181 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co573n-rwl-noaa.txt
# Min : 65 	---> Tree : 5
# Max : 171 	---> Tree : 8
# Avg : 112.1053
# ====== D O N E ====== : 182 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or059-rwl-noaa.txt
# Min : 118 	---> Tree : 18
# Max : 343 	---> Tree : 1
# Avg : 235.4500
# ====== D O N E ====== : 183 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co573w-rwl-noaa.txt
# Min : 65 	---> Tree : 5
# Max : 171 	---> Tree : 8
# Avg : 112.1053
# ====== D O N E ====== : 184 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co573x-rwl-noaa.txt
# Min : 65 	---> Tree : 5
# Max : 171 	---> Tree : 8
# Avg : 112.1053
# ====== D O N E ====== : 185 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co577l-rwl-noaa.txt
# Min : 91 	---> Tree : 18
# Max : 268 	---> Tree : 3
# Avg : 171.5714
# ====== D O N E ====== : 186 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co573l-rwl-noaa.txt
# Min : 65 	---> Tree : 5
# Max : 171 	---> Tree : 8
# Avg : 112.1053
# ====== D O N E ====== : 187 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  mt135-rwl-noaa.txt
# Min : 116 	---> Tree : 11
# Max : 218 	---> Tree : 1
# Avg : 169.8056
# ====== D O N E ====== : 188 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co577e-rwl-noaa.txt
# Min : 91 	---> Tree : 18
# Max : 268 	---> Tree : 3
# Avg : 171.5714
# ====== D O N E ====== : 189 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az564-rwl-noaa.txt
# Min : 52 	---> Tree : 2
# Max : 74 	---> Tree : 6
# Avg : 66.2500
# ====== D O N E ====== : 190 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co577n-rwl-noaa.txt
# Min : 91 	---> Tree : 18
# Max : 268 	---> Tree : 3
# Avg : 171.5714
# ====== D O N E ====== : 191 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co573p-rwl-noaa.txt
# Min : 65 	---> Tree : 5
# Max : 171 	---> Tree : 8
# Avg : 112.1053
# ====== D O N E ====== : 192 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or055-rwl-noaa.txt
# Min : 126 	---> Tree : 4
# Max : 574 	---> Tree : 15
# Avg : 307.4286
# ====== D O N E ====== : 193 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm619-rwl-noaa.txt
# Min : 61 	---> Tree : 35
# Max : 250 	---> Tree : 25
# Avg : 125.4048
# ====== D O N E ====== : 194 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or049-rwl-noaa.txt
# Min : 272 	---> Tree : 17
# Max : 661 	---> Tree : 4
# Avg : 411.0000
# ====== D O N E ====== : 195 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or053-rwl-noaa.txt
# Min : 110 	---> Tree : 7
# Max : 357 	---> Tree : 0
# Avg : 183.7895
# ====== D O N E ====== : 196 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or057-rwl-noaa.txt
# Min : 165 	---> Tree : 14
# Max : 546 	---> Tree : 6
# Avg : 312.2667
# ====== D O N E ====== : 197 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or048-rwl-noaa.txt
# Min : 210 	---> Tree : 9
# Max : 519 	---> Tree : 6
# Avg : 364.7241
# ====== D O N E ====== : 198 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or046-rwl-noaa.txt
# Min : 162 	---> Tree : 1
# Max : 468 	---> Tree : 7
# Avg : 351.0526
# ====== D O N E ====== : 199 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or052-rwl-noaa.txt
# Min : 148 	---> Tree : 18
# Max : 578 	---> Tree : 5
# Avg : 397.1481
# ====== D O N E ====== : 200 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or056-rwl-noaa.txt
# Min : 200 	---> Tree : 2
# Max : 427 	---> Tree : 12
# Avg : 309.4000
# ====== D O N E ====== : 201 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or058-rwl-noaa.txt
# Min : 154 	---> Tree : 6
# Max : 335 	---> Tree : 5
# Avg : 238.7500
# ====== D O N E ====== : 202 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or050-rwl-noaa.txt
# Min : 134 	---> Tree : 2
# Max : 250 	---> Tree : 1
# Avg : 198.2000
# ====== D O N E ====== : 203 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or047-rwl-noaa.txt
# Min : 246 	---> Tree : 6
# Max : 500 	---> Tree : 16
# Avg : 367.1667
# ====== D O N E ====== : 204 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wy034-rwl-noaa.txt
# Min : 65 	---> Tree : 13
# Max : 520 	---> Tree : 38
# Avg : 186.7250
# ====== D O N E ====== : 205 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or051-rwl-noaa.txt
# Min : 282 	---> Tree : 3
# Max : 422 	---> Tree : 4
# Avg : 378.1905
# ====== D O N E ====== : 206 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or054-rwl-noaa.txt
# Min : 221 	---> Tree : 6
# Max : 484 	---> Tree : 10
# Avg : 392.4000
# ====== D O N E ====== : 207 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm563-rwl-noaa.txt
# Min : 154 	---> Tree : 14
# Max : 209 	---> Tree : 0
# Avg : 182.8333
# ====== D O N E ====== : 208 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az026-rwl-noaa.txt
# Min : 112 	---> Tree : 4
# Max : 347 	---> Tree : 0
# Avg : 199.2222
# ====== D O N E ====== : 209 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm558-rwl-noaa.txt
# Min : 50 	---> Tree : 26
# Max : 351 	---> Tree : 14
# Avg : 243.2778
# ====== D O N E ====== : 210 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az036-rwl-noaa.txt
# Min : 51 	---> Tree : 5
# Max : 254 	---> Tree : 0
# Avg : 129.4167
# ====== D O N E ====== : 211 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co527-rwl-noaa.txt
# Min : 19 	---> Tree : 0
# Max : 180 	---> Tree : 57
# Avg : 94.3030
# ====== D O N E ====== : 212 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm007-rwl-noaa.txt
# Min : 151 	---> Tree : 10
# Max : 274 	---> Tree : 1
# Avg : 194.1429
# ====== D O N E ====== : 213 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ut507-rwl-noaa.txt
# Min : 56 	---> Tree : 10
# Max : 556 	---> Tree : 19
# Avg : 324.6818
# ====== D O N E ====== : 214 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az127-rwl-noaa.txt
# Min : 87 	---> Tree : 21
# Max : 343 	---> Tree : 24
# Avg : 233.5161
# ====== D O N E ====== : 215 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az045-rwl-noaa.txt
# Min : 137 	---> Tree : 1
# Max : 413 	---> Tree : 5
# Avg : 295.7500
# ====== D O N E ====== : 216 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm555-rwl-noaa.txt
# Min : 83 	---> Tree : 13
# Max : 389 	---> Tree : 7
# Avg : 255.8056
# ====== D O N E ====== : 217 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wy014-rwl-noaa.txt
# Min : 96 	---> Tree : 4
# Max : 422 	---> Tree : 7
# Avg : 263.3000
# ====== D O N E ====== : 218 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az049-rwl-noaa.txt
# Min : 190 	---> Tree : 24
# Max : 521 	---> Tree : 7
# Avg : 291.8929
# ====== D O N E ====== : 219 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ne003-rwl-noaa.txt
# Min : 65 	---> Tree : 5
# Max : 483 	---> Tree : 11
# Avg : 234.3667
# ====== D O N E ====== : 220 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wy017-rwl-noaa.txt
# Min : 98 	---> Tree : 9
# Max : 355 	---> Tree : 4
# Avg : 203.7895
# ====== D O N E ====== : 221 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az143-rwl-noaa.txt
# Min : 159 	---> Tree : 19
# Max : 330 	---> Tree : 2
# Avg : 260.3571
# ====== D O N E ====== : 222 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wy011-rwl-noaa.txt
# Min : 106 	---> Tree : 4
# Max : 299 	---> Tree : 0
# Avg : 207.2000
# ====== D O N E ====== : 223 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm061-rwl-noaa.txt
# Min : 119 	---> Tree : 3
# Max : 308 	---> Tree : 0
# Avg : 206.6000
# ====== D O N E ====== : 224 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or030-rwl-noaa.txt
# Min : 126 	---> Tree : 11
# Max : 491 	---> Tree : 26
# Avg : 299.7353
# ====== D O N E ====== : 225 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co526-rwl-noaa.txt
# Min : 29 	---> Tree : 8
# Max : 332 	---> Tree : 22
# Avg : 148.7742
# ====== D O N E ====== : 226 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm559-rwl-noaa.txt
# Min : 31 	---> Tree : 58
# Max : 981 	---> Tree : 53
# Avg : 349.9481
# ====== D O N E ====== : 227 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or029-rwl-noaa.txt
# Min : 56 	---> Tree : 12
# Max : 424 	---> Tree : 29
# Avg : 321.4545
# ====== D O N E ====== : 228 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co528-rwl-noaa.txt
# Min : 35 	---> Tree : 25
# Max : 126 	---> Tree : 38
# Avg : 76.0400
# ====== D O N E ====== : 229 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm561-rwl-noaa.txt
# Min : 49 	---> Tree : 20
# Max : 192 	---> Tree : 8
# Avg : 152.0000
# ====== D O N E ====== : 230 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm562-rwl-noaa.txt
# Min : 125 	---> Tree : 5
# Max : 350 	---> Tree : 11
# Avg : 178.1818
# ====== D O N E ====== : 231 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm556-rwl-noaa.txt
# Min : 131 	---> Tree : 15
# Max : 416 	---> Tree : 12
# Avg : 290.4286
# ====== D O N E ====== : 232 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm549-rwl-noaa.txt
# Min : 127 	---> Tree : 26
# Max : 350 	---> Tree : 7
# Avg : 278.6486
# ====== D O N E ====== : 233 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm551-rwl-noaa.txt
# Min : 106 	---> Tree : 21
# Max : 362 	---> Tree : 20
# Avg : 231.7727
# ====== D O N E ====== : 234 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm550-rwl-noaa.txt
# Min : 156 	---> Tree : 15
# Max : 456 	---> Tree : 16
# Avg : 330.1154
# ====== D O N E ====== : 235 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm554-rwl-noaa.txt
# Min : 81 	---> Tree : 16
# Max : 324 	---> Tree : 9
# Avg : 214.9474
# ====== D O N E ====== : 236 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm552-rwl-noaa.txt
# Min : 172 	---> Tree : 12
# Max : 402 	---> Tree : 16
# Avg : 254.3590
# ====== D O N E ====== : 237 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or031-rwl-noaa.txt
# Min : 168 	---> Tree : 8
# Max : 320 	---> Tree : 4
# Avg : 236.6000
# ====== D O N E ====== : 238 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or033-rwl-noaa.txt
# Min : 52 	---> Tree : 6
# Max : 419 	---> Tree : 4
# Avg : 240.0476
# ====== D O N E ====== : 239 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca694-rwl-noaa.txt
# Min : 81 	---> Tree : 14
# Max : 187 	---> Tree : 23
# Avg : 108.5750
# ====== D O N E ====== : 240 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co529-rwl-noaa.txt
# Min : 87 	---> Tree : 1
# Max : 260 	---> Tree : 21
# Avg : 152.8710
# ====== D O N E ====== : 241 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm553-rwl-noaa.txt
# Min : 130 	---> Tree : 9
# Max : 233 	---> Tree : 6
# Avg : 163.7000
# ====== D O N E ====== : 242 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co531-rwl-noaa.txt
# Min : 71 	---> Tree : 9
# Max : 271 	---> Tree : 11
# Avg : 154.6800
# ====== D O N E ====== : 243 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca694e-rwl-noaa.txt
# Min : 81 	---> Tree : 14
# Max : 187 	---> Tree : 23
# Avg : 107.6500
# ====== D O N E ====== : 244 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co530-rwl-noaa.txt
# Min : 46 	---> Tree : 5
# Max : 124 	---> Tree : 1
# Avg : 91.7500
# ====== D O N E ====== : 245 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or038-rwl-noaa.txt
# Min : 102 	---> Tree : 41
# Max : 327 	---> Tree : 28
# Avg : 273.7381
# ====== D O N E ====== : 246 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca695-rwl-noaa.txt
# Min : 88 	---> Tree : 31
# Max : 178 	---> Tree : 6
# Avg : 112.6842
# ====== D O N E ====== : 247 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm557-rwl-noaa.txt
# Min : 141 	---> Tree : 0
# Max : 445 	---> Tree : 13
# Avg : 291.7742
# ====== D O N E ====== : 248 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or034-rwl-noaa.txt
# Min : 100 	---> Tree : 1
# Max : 231 	---> Tree : 12
# Avg : 166.4211
# ====== D O N E ====== : 249 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or039-rwl-noaa.txt
# Min : 86 	---> Tree : 31
# Max : 407 	---> Tree : 39
# Avg : 172.0227
# ====== D O N E ====== : 250 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ca694l-rwl-noaa.txt
# Min : 81 	---> Tree : 14
# Max : 187 	---> Tree : 23
# Avg : 107.6250
# ====== D O N E ====== : 251 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or035-rwl-noaa.txt
# Min : 122 	---> Tree : 2
# Max : 327 	---> Tree : 5
# Avg : 276.4211
# ====== D O N E ====== : 252 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or032-rwl-noaa.txt
# Min : 118 	---> Tree : 6
# Max : 442 	---> Tree : 23
# Avg : 298.4444
# ====== D O N E ====== : 253 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa142-rwl-noaa.txt
# Min : 93 	---> Tree : 29
# Max : 550 	---> Tree : 40
# Avg : 319.6170
# ====== D O N E ====== : 254 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa139-rwl-noaa.txt
# Min : 170 	---> Tree : 5
# Max : 414 	---> Tree : 23
# Avg : 300.7333
# ====== D O N E ====== : 255 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wy058-rwl-noaa.txt
# Min : 180 	---> Tree : 13
# Max : 441 	---> Tree : 10
# Avg : 328.7500
# ====== D O N E ====== : 256 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa138-rwl-noaa.txt
# Min : 48 	---> Tree : 36
# Max : 435 	---> Tree : 34
# Avg : 305.6000
# ====== D O N E ====== : 257 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  id015-rwl-noaa.txt
# Min : 139 	---> Tree : 0
# Max : 525 	---> Tree : 5
# Avg : 235.3824
# ====== D O N E ====== : 258 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or041-rwl-noaa.txt
# Min : 116 	---> Tree : 5
# Max : 279 	---> Tree : 1
# Avg : 190.1250
# ====== D O N E ====== : 259 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa140-rwl-noaa.txt
# Min : 134 	---> Tree : 14
# Max : 502 	---> Tree : 36
# Avg : 322.8205
# ====== D O N E ====== : 260 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa141-rwl-noaa.txt
# Min : 129 	---> Tree : 18
# Max : 393 	---> Tree : 21
# Avg : 269.8158
# ====== D O N E ====== : 261 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa136-rwl-noaa.txt
# Min : 177 	---> Tree : 10
# Max : 625 	---> Tree : 22
# Avg : 337.8000
# ====== D O N E ====== : 262 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or040-rwl-noaa.txt
# Min : 137 	---> Tree : 12
# Max : 318 	---> Tree : 16
# Avg : 247.4286
# ====== D O N E ====== : 263 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az560-rwl-noaa.txt
# Min : 71 	---> Tree : 13
# Max : 197 	---> Tree : 1
# Avg : 141.2000
# ====== D O N E ====== : 264 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  or037-rwl-noaa.txt
# Min : 130 	---> Tree : 4
# Max : 232 	---> Tree : 23
# Avg : 172.9167
# ====== D O N E ====== : 265 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wa137-rwl-noaa.txt
# Min : 85 	---> Tree : 17
# Max : 366 	---> Tree : 23
# Avg : 255.4000
# ====== D O N E ====== : 266 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm573-rwl-noaa.txt
# Min : 102 	---> Tree : 29
# Max : 316 	---> Tree : 4
# Avg : 182.7812
# ====== D O N E ====== : 267 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co596-rwl-noaa.txt
# Min : 94 	---> Tree : 21
# Max : 460 	---> Tree : 19
# Avg : 265.1379
# ====== D O N E ====== : 268 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm591-rwl-noaa.txt
# Min : 50 	---> Tree : 5
# Max : 445 	---> Tree : 56
# Avg : 240.1383
# ====== D O N E ====== : 269 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co564-rwl-noaa.txt
# Min : 114 	---> Tree : 5
# Max : 290 	---> Tree : 21
# Avg : 165.5455
# ====== D O N E ====== : 270 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az562-rwl-noaa.txt
# Min : 57 	---> Tree : 0
# Max : 291 	---> Tree : 5
# Avg : 156.6667
# ====== D O N E ====== : 271 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm574-rwl-noaa.txt
# Min : 101 	---> Tree : 12
# Max : 338 	---> Tree : 21
# Avg : 211.3571
# ====== D O N E ====== : 272 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co591-rwl-noaa.txt
# Min : 113 	---> Tree : 18
# Max : 580 	---> Tree : 31
# Avg : 410.7222
# ====== D O N E ====== : 273 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co590-rwl-noaa.txt
# Min : 113 	---> Tree : 20
# Max : 482 	---> Tree : 4
# Avg : 222.7105
# ====== D O N E ====== : 274 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co659-rwl-noaa.txt
# Min : 153 	---> Tree : 2
# Max : 315 	---> Tree : 11
# Avg : 205.2188
# ====== D O N E ====== : 275 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm575-rwl-noaa.txt
# Min : 135 	---> Tree : 12
# Max : 281 	---> Tree : 5
# Avg : 204.0000
# ====== D O N E ====== : 276 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co594-rwl-noaa.txt
# Min : 144 	---> Tree : 22
# Max : 565 	---> Tree : 33
# Avg : 323.8710
# ====== D O N E ====== : 277 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az561-rwl-noaa.txt
# Min : 67 	---> Tree : 1
# Max : 340 	---> Tree : 3
# Avg : 165.0588
# ====== D O N E ====== : 278 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ne008-rwl-noaa.txt
# Min : 103 	---> Tree : 29
# Max : 425 	---> Tree : 42
# Avg : 191.0000
# ====== D O N E ====== : 279 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co657-rwl-noaa.txt
# Min : 78 	---> Tree : 29
# Max : 310 	---> Tree : 35
# Avg : 199.3556
# ====== D O N E ====== : 280 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ne007-rwl-noaa.txt
# Min : 131 	---> Tree : 5
# Max : 358 	---> Tree : 10
# Avg : 252.6667
# ====== D O N E ====== : 281 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co598-rwl-noaa.txt
# Min : 146 	---> Tree : 2
# Max : 455 	---> Tree : 23
# Avg : 294.5769
# ====== D O N E ====== : 282 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  az585-rwl-noaa.txt
# Min : 32 	---> Tree : 53
# Max : 418 	---> Tree : 99
# Avg : 175.5396
# ====== D O N E ====== : 283 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co607-rwl-noaa.txt
# Min : 202 	---> Tree : 16
# Max : 648 	---> Tree : 2
# Avg : 336.2917
# ====== D O N E ====== : 284 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co569-rwl-noaa.txt
# Min : 132 	---> Tree : 9
# Max : 368 	---> Tree : 14
# Avg : 278.0588
# ====== D O N E ====== : 285 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co669-rwl-noaa.txt
# Min : 131 	---> Tree : 15
# Max : 374 	---> Tree : 3
# Avg : 227.1667
# ====== D O N E ====== : 286 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co601-rwl-noaa.txt
# Min : 94 	---> Tree : 33
# Max : 469 	---> Tree : 11
# Avg : 264.6842
# ====== D O N E ====== : 287 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co588-rwl-noaa.txt
# Min : 123 	---> Tree : 6
# Max : 374 	---> Tree : 19
# Avg : 220.9000
# ====== D O N E ====== : 288 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co666-rwl-noaa.txt
# Min : 133 	---> Tree : 11
# Max : 382 	---> Tree : 24
# Avg : 219.0000
# ====== D O N E ====== : 289 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co608-rwl-noaa.txt
# Min : 125 	---> Tree : 20
# Max : 518 	---> Tree : 10
# Avg : 250.0714
# ====== D O N E ====== : 290 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co611-rwl-noaa.txt
# Min : 93 	---> Tree : 1
# Max : 451 	---> Tree : 8
# Avg : 236.7941
# ====== D O N E ====== : 291 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co568-rwl-noaa.txt
# Min : 102 	---> Tree : 16
# Max : 249 	---> Tree : 13
# Avg : 157.2903
# ====== D O N E ====== : 292 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co639-rwl-noaa.txt
# Min : 82 	---> Tree : 9
# Max : 384 	---> Tree : 16
# Avg : 244.4483
# ====== D O N E ====== : 293 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ne006-rwl-noaa.txt
# Min : 88 	---> Tree : 16
# Max : 227 	---> Tree : 30
# Avg : 154.0645
# ====== D O N E ====== : 294 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co602-rwl-noaa.txt
# Min : 139 	---> Tree : 5
# Max : 438 	---> Tree : 22
# Avg : 294.0833
# ====== D O N E ====== : 295 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm577-rwl-noaa.txt
# Min : 88 	---> Tree : 19
# Max : 316 	---> Tree : 7
# Avg : 231.5417
# ====== D O N E ====== : 296 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm595-rwl-noaa.txt
# Min : 69 	---> Tree : 20
# Max : 449 	---> Tree : 63
# Avg : 178.1860
# ====== D O N E ====== : 297 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm582-rwl-noaa.txt
# Min : 90 	---> Tree : 37
# Max : 430 	---> Tree : 32
# Avg : 250.6429
# ====== D O N E ====== : 298 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co565-rwl-noaa.txt
# Min : 99 	---> Tree : 9
# Max : 194 	---> Tree : 8
# Avg : 151.1250
# ====== D O N E ====== : 299 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  wy032-rwl-noaa.txt
# Min : 125 	---> Tree : 29
# Max : 492 	---> Tree : 10
# Avg : 270.9091
# ====== D O N E ====== : 300 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co675-rwl-noaa.txt
# Min : 99 	---> Tree : 23
# Max : 371 	---> Tree : 18
# Avg : 200.7391
# ====== D O N E ====== : 301 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co622-rwl-noaa.txt
# Min : 114 	---> Tree : 6
# Max : 568 	---> Tree : 11
# Avg : 302.7838
# ====== D O N E ====== : 302 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co625-rwl-noaa.txt
# Min : 178 	---> Tree : 34
# Max : 438 	---> Tree : 20
# Avg : 325.8857
# ====== D O N E ====== : 303 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co623-rwl-noaa.txt
# Min : 212 	---> Tree : 19
# Max : 491 	---> Tree : 16
# Avg : 336.1500
# ====== D O N E ====== : 304 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co627-rwl-noaa.txt
# Min : 1 	---> Tree : 41
# Max : 460 	---> Tree : 29
# Avg : 245.9286
# ====== D O N E ====== : 305 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co641-rwl-noaa.txt
# Min : 44 	---> Tree : 8
# Max : 384 	---> Tree : 22
# Avg : 220.5517
# ====== D O N E ====== : 306 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm610-rwl-noaa.txt
# Min : 47 	---> Tree : 25
# Max : 378 	---> Tree : 52
# Avg : 204.2326
# ====== D O N E ====== : 307 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  ne005-rwl-noaa.txt
# Min : 99 	---> Tree : 34
# Max : 272 	---> Tree : 25
# Avg : 155.4324
# ====== D O N E ====== : 308 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co570-rwl-noaa.txt
# Min : 68 	---> Tree : 13
# Max : 341 	---> Tree : 43
# Avg : 169.5000
# ====== D O N E ====== : 309 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm605-rwl-noaa.txt
# Min : 67 	---> Tree : 24
# Max : 446 	---> Tree : 53
# Avg : 210.9444
# ====== D O N E ====== : 310 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co653-rwl-noaa.txt
# Min : 50 	---> Tree : 53
# Max : 436 	---> Tree : 33
# Avg : 245.0667
# ====== D O N E ====== : 311 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  co654-rwl-noaa.txt
# Min : 70 	---> Tree : 32
# Max : 341 	---> Tree : 35
# Avg : 162.7593
# ====== D O N E ====== : 312 of 313 Files
#
#
#  ====== S T A R T I N G ====== :  nm612-rwl-noaa.txt
# Min : 70 	---> Tree : 36
# Max : 352 	---> Tree : 45
# Avg : 206.3750
# ====== D O N E ====== : 313 of 313 Files

# %%
min_val = min(min_info)
max_val = max(min_info)
avg_val = sum(min_info) / len(min_info)
print(f"Min information : {min_val}")
print(f"Max information : {max_val}")
print(f"Avg information : {avg_val:.0f}")
# Out:
# Min information : 1
# Max information : 316
# Avg information : 113

# %%
min_early = min(early)
max_late = max(late)

# %%
print("Earliest First Date : ", min_early)
print("Latest Last Date    : ", max_late)
# Out:
# Earliest First Date :  532
# Latest Last Date    :  2020

# %%
print(f"Total Trees : {sum(len_info)}")
# Out:
# Total Trees : 10141
