# %% [markdown]
# <a href="https://colab.research.google.com/github/SMRayeed/Paleo-Data-Classification/blob/main/02_Data_Processing_PIPO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folder_path = '/content/drive/MyDrive/PIPO/processed/Files(.csv)/'
files = os.listdir(folder_path)

# %%
drive_path_csv = '/content/drive/MyDrive/PIPO/sized/'
os.makedirs(drive_path_csv) if not os.path.exists(drive_path_csv) else None

# %%
years_range = range(1, 2024)

# %%
dfs = []

# %%
for item in files :
  df = pd.read_csv(folder_path + item)

  for year in years_range:
    column_name = str(year)
    if column_name not in df.columns : df[column_name] = float('nan')

  df = df.reindex(sorted(df.columns, key=lambda x: int(x) if x.isdigit() else float('inf')), axis=1)
  non_year_columns = [col for col in df.columns if not col.isdigit()]
  column_order = ['index'] + sorted(list(map(str, range(1, 2024))), key=lambda x: int(x)) + non_year_columns
  df = df[column_order]
  column_index_to_drop = df.shape[1] - 8
  df = df.iloc[:, :column_index_to_drop].join(df.iloc[:, column_index_to_drop + 1:])

  assert len(df.columns.to_list()) == 2031 , "BUG"
  if len(df.columns.to_list()) != 2031 : print(item)

  output_csv_file_path = drive_path_csv + item
  df.to_csv(output_csv_file_path, index=False)
  dfs.append(df)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-9-d50ad25ee3c3>:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   if column_name not in df.columns : df[column_name] = float('nan')
# <ipython-input-9-d50ad25ee3c3>:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   if column_name not in df.columns : df[column_name] = float('nan')
# ...

# %%
merged_df = pd.concat(dfs, ignore_index=True)

# %%
merged_df
# Out:
#            index   1   2   3   4   5   6   7   8   9  ...  2021  2022  2023  \
# 0     kim021_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 1     kim041_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 2     kim042_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 3     kim052_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 4     kim053_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# ...          ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...   ...   ...   ...
# 9730  VPB121_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 9731  VPB122_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 9732  VPB141_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 9733  VPB142_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 9734  VPB143_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
#
# ...

# %%
merged_df.to_csv('/content/drive/MyDrive/PIPO/merged_df.csv', index=False)

# %% [markdown]
# #### Merge with Previous one

# %%
df_merged_prev = pd.read_csv('/content/drive/MyDrive/AI4C-Project/merged_df.csv')
df_merged_pipo = pd.read_csv('/content/drive/MyDrive/PIPO/merged_df.csv')

# %%
print(f"Previously : No. of Trees ---> {df_merged_prev.shape[0]} \t Columns ---> {df_merged_prev.shape[1]}")
print(f"PIPO Merge : No. of Trees ---> {df_merged_pipo.shape[0]} \t Columns ---> {df_merged_pipo.shape[1]}")
# Out:
# Previously : No. of Trees ---> 18902 	 Columns ---> 2031
# PIPO Merge : No. of Trees ---> 9735 	 Columns ---> 2031

# %%
final_merge_dfs = [df_merged_prev, df_merged_pipo]

# %%
final_merge = pd.concat(final_merge_dfs, ignore_index=True)

# %%
final_merge.head(10)
# Out:
#         index   1   2   3   4   5   6   7   8   9  ...  2021  2022  2023  \
# 0  GRM101_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 1  GRM107_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 2  GRM108_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 3  GRM109_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 4  GRM110_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 5  GRM120_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 6  GRM124_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 7  GRM126_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 8  GRM127_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
# 9  GRM128_raw NaN NaN NaN NaN NaN NaN NaN NaN NaN  ...   NaN   NaN   NaN
#
#                 site      loc        N        S         E         W  species
# 0  Grass Mountain #1  Montana  45.1667  45.1667 -109.5167 -109.5167     PIAL
# ...

# %%
final_merge.to_csv('/content/drive/MyDrive/AI4C-Project/final_merged_df.csv', index=False)
